# %%
from bs4 import BeautifulSoup
import requests
import re
import urllib.request

# %% [markdown]
# 1. load https://www.tigerdirect.com/applications/SearchTools/item-details.asp?EdpNo=1501390

# %%
my_headers = {'User-Agent': 'Mozilla/5.0'}
url = requests.get('https://www.tigerdirect.com/applications/SearchTools/item-details.asp?EdpNo=1501390', headers=my_headers) 
soup = BeautifulSoup(url.content) 
print(soup.prettify())

# %% [markdown]
# 2. Use your browser's development tools to find a unique way to access its list price and its current price. What do you choose? Please remember, you can choose multiple selectors to get where you want to be. E.g., you may choose to select "span.class1 p.class2" to select the "p" of class "class2" inside of the "span" of class "class1".

# %%
def main():
	try:
		url= "https://www.tigerdirect.com/applications/SearchTools/item-details.asp?EdpNo=1501390"
		my_headers = {'User-Agent': 'Mozilla/5.0'}
		page = requests.get(url, headers=my_headers)
		# Create a beautifulsoup object 
		soup = BeautifulSoup(page.text, 'lxml')
		# find <p> that immediately follows <div> of class "col-md-6.
		list_of_contents = soup.select("p.list-price span.sr-only")
		list_of_contents_2 = soup.select("p.final-price span.sr-only")
		# prints the HTML content to the screen (almost only text here
		# just need to replaces "&nbsp;" with " ")
		for i in list_of_contents:
			a = i.text
			print(i.text)
		
		for i in list_of_contents_2:
			b = i.text
			print(i.text)
		
		return a, b
	except:
		print("Problem with the connection...")

if __name__ == '__main__':
	main()
# Out:
# $1,399
#           and 99 cents
#
# $1,029
#           and 99 cents

# %% [markdown]
# 3. store the prices to strings.

# %%
def convertTuple(tup):
    str = ''.join(tup)
    return str

str = convertTuple(main())
print(str)
# Out:
# $1,399
#           and 99 cents
#
# $1,029
#           and 99 cents
#
# $1,399
#           and 99 cents
#         $1,029
#           and 99 cents

# %% [markdown]
# 4. Use Python's (or Java's) regex (!!) functionality to convert the prices to "1234.56" (no dollar sign, comma, just a "." separator for cents)

# %%
temp1 = re.sub(r"and ", ".", str)
temp2 = re.sub(r"[$,\r\n ]+", "", temp1)
temp3 = re.sub(r"[a-z]+", "\n", temp2)
print(temp3)
# Out:
# 1399.99
# 1029.99

# %% [markdown]
# 5. print both, the list price and the current price to screen / terminal

# %%
print(temp3)

# %% [markdown]
# 6. Write code that loads "https://www.usnews.com/"

# %%
my_headers = {'User-Agent': 'Mozilla/5.0'}
url = requests.get('https://www.usnews.com/', headers=my_headers) 
soup = BeautifulSoup(url.content) 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- component="containers/pages/brightspot/homepage/index.js" -->
# <!-- build="static-atlas-master 1354" -->
# <html lang="en">
#  <head>
#   <link href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@300;400;500;700&amp;family=Montserrat:wght@400;600;700&amp;display=fallback" rel="stylesheet"/>
#   <title data-rh="true">
#    U.S. News &amp; World Report: News, Rankings and Analysis on Politics, Education, Healthcare and More
#   </title>
#   <meta charset="utf-8" data-rh="true"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" data-rh="true" name="viewport"/>
#   <meta content="US News is a recognized leader in college, grad school, hospital, mutual fund, and car rankings. Track elected officials, research health conditions, and find news you can use in politics, business, health, and education." data-rh="true" name="description"/>
#   <meta content="usnhomepage" data-rh="true" name="keywords"/>
#   <meta content="homepage" data-rh="true" name="site"/>
#   <meta content="home" data-rh="true" name="zone"/>
#   <meta content="max-image-preview:large" data-rh="true" name="robots"/>
#   <meta content="5834919267" data-rh="true" property="fb:pages"/>
#   <meta content="0000015e-77a8-da21-a15f-ffed9f560000" data-rh="true" name="brightspot.contentId"/>
#   <meta content="U.S. News &amp; World Report: News, Rankings and Analysis on Politics, Education, Healthcare and More" data-rh="true" property="og:title"/>
#   <meta content="US News is a recognized leader in college, grad school, hospital, mutual fund, and car rankings.  Track elected officials, research health conditions, and find news you can use in politics, business, health, and education." data-rh="true" property="og:description"/>
#   <meta content="U.S. News &amp; World Report: News, Rankings and Analysis on Politics, Education, Healthcare and More" data-rh="true" property="twitter:title"/>
#   <meta content="US News is a recognized leader in college, grad school, hospital, mutual fund, and car rankings.  Track elected officials, research health conditions, and find news you can use in politics, business, health, and education." data-rh="true" property="twitter:description"/>
#   <meta content="@USNews" data-rh="true" property="twitter:site"/>
#   <meta content="summary" data-rh="true" property="twitter:card"/>
#   <meta content="Optimizely is supported by this application but is not enabled for this page." data-rh="true" property="optimizely"/>
#   <script data-rh="true">
#    window.usnFirstByteTime = new Date();
#         performance && performance.mark && performance.mark('ttfb');
#   </script>
#   <script data-rh="true" type="text/javascript">
#    var utag_data = {"site_portal":"null","site_product_subsection":"","content_type":"editorial","page_type":"sectionfront","site_product_section":"","site_product":"","site_vertical":"Homepage","stitial_fact":"The average amount of student loan debt is $29,400.","page_container":"containers/pages/brightspot/homepage/index.js","tealium_environment":"prod","site_version":"atlas"};
#         (function() {
#             function usnRandId() {return (new Date().getTime() % 100000000000 + Math.random()).toString().replace(".", "");}
#             function get(name) {return (("; " + document.cookie).split("; " + name + "=")[1] || "").split(";")[0];}
#             function cookie(name, val) {return name + "=" + val + "; path=/; domain=.usnews.com";}
#             function permacookie(name, val) {var d = new Date();d.setTime(d.getTime() + 365 * 24 * 60 * 60 * 1000);return cookie(name, val) + "; expires=" + d.toUTCString();}
#             window.usn_permacookie = permacookie;
#             var usn_pageview_id = usnRandId();
#             var usn_session_id = get("usn_session_id");
#             if (!usn_session_id) {
#                 usn_session_id = usnRandId();
#                 document.cookie = cookie("usn_session_id", usn_session_id);
#             }
#             var usn_visitor_id = get("usn_visitor_id");
#             if (!usn_visitor_id) {
#                 // This should always be set by Akamai, but if not, fake it here.
#                 usn_visitor_id = usnRandId();
#                 document.cookie = permacookie("usn_visitor_id", usn_visitor_id);
#             }
#             var usn_src = get("usn_src");
#             var query = window.location.search && window.location.search.substr(1).split('&');
#             if (query) {
#                 var pair;
#                 while (pair = query.pop()) {
#                     if (pair.indexOf("src=") === 0) {
#                         var src = pair.substr(4);
#                         usn_src = usn_src || src;
#                         if (usn_src.indexOf(src) === -1) {
#                             usn_src += ',' + src;
#                         }
#                         document.cookie = permacookie("usn_src", usn_src);
#                     }
#                 }
#             }
#             var vertical = utag_data.site_vertical && utag_data.site_vertical.toLowerCase();
#             if (vertical && vertical !== 'generic') {
#                 document.cookie = cookie("cogv", vertical);
#             }
#             utag_data.usn_src = usn_src;
#             utag_data.usn_pageview_id = usn_pageview_id;
#             utag_data.usn_hit_id = usnRandId();
#             utag_data.usn_session_id = usn_session_id;
#             utag_data.usn_visitor_id = usn_visitor_id;
#
#             function identify_utag_data() {
#                 var awsCognitoEmail = get("coge");
#
#                 if (awsCognitoEmail) {
#                     // Sanitize email address
#                     awsCognitoEmail = awsCognitoEmail.trim().toLowerCase();
#                 }
#
#                 utag_data.aws_cognito_sub = get("cogsub");
#                 utag_data.aws_cognito_email = awsCognitoEmail;
#                 utag_data.sailthru_email_hashed = get("usn_sailthru_hash");
#             }
#
#             identify_utag_data();
#             window.usn_identify_utag_data = identify_utag_data;
#
#             // Global Privacy Control is not supported by many browsers but legally required to respond to
#             if (typeof(navigator) !== 'undefined' && navigator.globalPrivacyControl) {
#                 document.cookie = permacookie("usprivacy", "1YYY");
#             }
#         }());
#   </script>
#   <script crossorigin="anonymous" data-rh="true" defer="true" integrity="sha256-9/aliU8dGd2tb6OSsuzixeV4y/faTqgFtohetphbbj0=" src="https://code.jquery.com/jquery-3.5.1.min.js">
#   </script>
#   <script data-rh="true" defer="true" src="https://tags.tiqcdn.com/utag/usnews/main/prod/utag.js">
#   </script>
#   <script data-env="null" data-rh="true" id="request-info" type="application/json">
#    {"environment":null,"port":null,"environment_affix":"","subdomain":"www","request_url":"https://www.usnews.com/"}
#   </script>
#   <script data-partner-name="nativo" data-rh="true">
#    //This is a hack to trick Tealium into thinking Nativo is on the page so we can control when it loads.
#   </script>
#   <style data-rh="true">
#    /* Stop smooth scrolling if reduced-motion is enabled */
#         @media (prefers-reduced-motion: reduce) {
#             html {
#                 scroll-behavior: auto !important;
#             }
#         }
#   </style>
#   <link data-rh="true" href="/static/images/favicon.ico" rel="shortcut icon"/>
#   <link data-rh="true" href="/static-atlas/assets/img/social-logo-world-report.png" rel="apple-touch-icon" type="image/png"/>
#   <link data-rh="true" data-test-id="relCanonical" href="https://www.usnews.com" rel="canonical"/>
#   <link as="script" data-rh="true" href="https://cse.google.com/cse.js?cx=009692862532464842631:ckoj05188pi" rel="prefetch"/>
#   <style data-styled="true" data-styled-version="5.3.3">
#    :root{--black-90:#1A1D26;--black-80:#2C303C;--black-70:#3F4451;--gray-50:#515767;--gray-30:#6F7480;--gray-20:#9297A1;--gray-15:#D3D7DC;--gray-10:#E4E7EB;--gray-05:#F4F7F9;--white-00:#ffffff;--red-90:#871A18;--red-80:#A4211F;--red-70:#B92523;--red-50:#CE2927;--red-30:#EB625F;--red-20:#F58987;--red-15:#FCBAB9;--red-10:#FDD5D4;--red-05:#FFF0EF;--orange-90:#C94D00;--orange-80:#DD7E00;--orange-70:#E89A00;--yellow-50:#F1B303;--yellow-30:#F7CE27;--yellow-20:#FBE25C;--yellow-15:#FEF2A0;--yellow-10:#FEF8C6;--yellow-05:#FFFDEB;--green-90:#024024;--green-80:#005E31;--green-70:#06844B;--green-50:#24BB80;--green-30:#38D38D;--green-20:#97EFB2;--green-15:#C4F9D6;--green-10:#DBFBE8;--green-05:#F0FFEF;--blue-90:#00206B;--blue-80:#033493;--blue-70:#064AB7;--blue-50:#1263D3;--blue-30:#358CE7;--blue-20:#6AB4F4;--blue-15:#B1DCFB;--blue-10:#D6EEFD;--blue-05:#EFF8FF;--violet-90:#240C33;--violet-80:#3D1455;--violet-70:#512386;--violet-50:#5A37AE;--violet-30:#624FCC;--violet-20:#7D79DF;--violet-15:#97A3F1;--violet-10:#C7D4FA;--violet-05:#E9EEFC;--muted:#515767;--font-primary:"Roboto",Helvetica Neue,Helvetica,sans-serif;--font-secondary:"Montserrat",Helvetica Neue,Helvetica,sans-serif;font-family:var(--font-primary);-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;text-rendering:optimizeLegibility;-webkit-text-size-adjust:none;text-size-adjust:none;color:var(--black-90);}/*!sc*/
# html{background-color:var(--white-00);}/*!sc*/
# a{-webkit-text-decoration:none;text-decoration:none;color:var(--blue-50);-webkit-transition:color 0.5s;transition:color 0.5s;}/*!sc*/
# a:hover,a:active{color:var(--blue-90);}/*!sc*/
# data-styled.g1[id="sc-global-fYTvay1"]{content:"sc-global-fYTvay1,"}/*!sc*/
# .eJAyFO{position:fixed;left:1rem;bottom:68px;max-width:calc(100% - 2rem);box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;z-index:10000;}/*!sc*/
# @media (min-width:640px){.eJAyFO{max-width:415px;}}/*!sc*/
# @media (min-width:1024px){.eJAyFO{bottom:125px;}}/*!sc*/
# data-styled.g66[id="overlay__Container-sc-1mwbfqy-0"]{content:"eJAyFO,"}/*!sc*/
# html{background-color:var(--black-90);-webkit-scroll-behavior:smooth;-moz-scroll-behavior:smooth;-ms-scroll-behavior:smooth;scroll-behavior:smooth;-webkit-scroll-padding-top:4rem;-moz-scroll-padding-top:4rem;-ms-scroll-padding-top:4rem;scroll-padding-top:4rem;}/*!sc*/
# @media (prefers-reduced-motion:reduce){html{-webkit-scroll-behavior:auto !important;-moz-scroll-behavior:auto !important;-ms-scroll-behavior:auto !important;scroll-behavior:auto !important;}}/*!sc*/
# html[data-disable-js=true] [data-test-remove=true]{display:none;}/*!sc*/
# body{background-color:var(--white-00);min-height:100vh;margin:0;overflow-x:hidden;}/*!sc*/
# lazy-background{box-sizing:border-box;}/*!sc*/
# data-styled.g67[id="sc-global-gczUDA1"]{content:"sc-global-gczUDA1,"}/*!sc*/
# div{box-sizing:border-box;}/*!sc*/
# .hide{display:none!important;}/*!sc*/
# @media (max-width:639px){.sm-hide{display:none!important;}}/*!sc*/
# @media (min-width:640px) and (max-width:1023px){.md-hide{display:none!important;}}/*!sc*/
# @media (min-width:1024px){.lg-hide{display:none!important;}}/*!sc*/
# @media (min-width:640px) and (max-width:767px){.ms-hide{display:none!important;}}/*!sc*/
# @media (min-width:768px) and (max-width:1023px){.ml-hide{display:none!important;}}/*!sc*/
# .visually-hidden{position:absolute;height:1px;width:1px;padding:0;margin:-1px;border:0;-webkit-clip:rect(0,0,0,0);clip:rect(0,0,0,0);overflow:hidden;}/*!sc*/
# .flex{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .flex-column{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .white{color:#fff;}/*!sc*/
# .gray{color:#ccc;}/*!sc*/
# .lightgray{color:#f7f7f7;}/*!sc*/
# .darkgray{color:#666;}/*!sc*/
# .bg-gray{background-color:#ccc;}/*!sc*/
# .bg-lightgray{background-color:#f7f7f7;}/*!sc*/
# .bg-darkgray{background-color:#666;}/*!sc*/
# .black90{color:#111;}/*!sc*/
# .black80{color:#222;}/*!sc*/
# .black70{color:#333;}/*!sc*/
# .t0,.t1,.t2,.t3,.t4,.t5,.t6,.t7,.t-font-fam{font-family:Roboto,Helvetica Neue,Helvetica,sans-serif;margin:0;}/*!sc*/
# .t0{font-size:.625rem;line-height:1.2;}/*!sc*/
# .t1{font-size:.75rem;line-height:1.3;}/*!sc*/
# .t2{font-size:.875rem;line-height:1.4;}/*!sc*/
# .t3{font-size:1rem;}/*!sc*/
# .t3,.t4{line-height:1.5;}/*!sc*/
# .t4{font-size:1.125rem;}/*!sc*/
# .t5{font-size:1.25rem;line-height:1.4;}/*!sc*/
# .t6{font-size:1.5rem;line-height:1.33;}/*!sc*/
# .t7{font-size:2rem;line-height:1.25;}/*!sc*/
# @media (min-width:640px) and (max-width:1023px){.md-t0{font-size:.625rem;line-height:1.2;}.md-t1{font-size:.75rem;line-height:1.3;}.md-t2{font-size:.875rem;line-height:1.4;}.md-t3{font-size:1rem;}.md-t3,.md-t4{line-height:1.5;}.md-t4{font-size:1.125rem;}.md-t5{font-size:1.25rem;line-height:1.4;}.md-t6{font-size:1.5rem;line-height:1.33;}.md-t7{font-size:2rem;line-height:1.25;}}/*!sc*/
# @media (min-width:768px) and (max-width:1023px){.ml-t0{font-size:.625rem;line-height:1.2;}.ml-t1{font-size:.75rem;line-height:1.3;}.ml-t2{font-size:.875rem;line-height:1.4;}.ml-t3{font-size:1rem;}.ml-t3,.ml-t4{line-height:1.5;}.ml-t4{font-size:1.125rem;}.ml-t5{font-size:1.25rem;line-height:1.4;}.ml-t6{font-size:1.5rem;line-height:1.33;}.ml-t7{font-size:2rem;line-height:1.25;}}/*!sc*/
# @media (min-width:1024px){.lg-t0{font-size:.625rem;line-height:1.2;}.lg-t1{font-size:.75rem;line-height:1.3;}.lg-t2{font-size:.875rem;line-height:1.4;}.lg-t3{font-size:1rem;}.lg-t3,.lg-t4{line-height:1.5;}.lg-t4{font-size:1.125rem;}.lg-t5{font-size:1.25rem;line-height:1.4;}.lg-t6{font-size:1.5rem;line-height:1.33;}.lg-t7{font-size:2rem;line-height:1.25;}}/*!sc*/
# .h0,.h1,.h2,.h3,.h4,.h5,.h6,.h7,.h8,.h-font-fam{font-family:Montserrat,Helvetica Neue,Helvetica,sans-serif;margin:0;padding:0;}/*!sc*/
# .h0{font-size:.75rem;line-height:1.33;}/*!sc*/
# .h1{font-size:.875rem;line-height:1.42;}/*!sc*/
# .h2{font-size:1rem;line-height:1.25;}/*!sc*/
# .h3{font-size:1.125rem;line-height:1.33;}/*!sc*/
# .h4{font-size:1.25rem;line-height:1.2;}/*!sc*/
# .h5{font-size:1.5rem;line-height:1.33;}/*!sc*/
# .h6{font-size:2rem;line-height:1.25;}/*!sc*/
# .h7{font-size:2.625rem;line-height:1.14;}/*!sc*/
# .h8{font-size:3.125rem;line-height:1.12;}/*!sc*/
# @media (min-width:640px) and (max-width:1023px){.md-h0{font-size:.75rem;line-height:1.33;}.md-h1{font-size:.875rem;line-height:1.42;}.md-h2{font-size:1rem;line-height:1.25;}.md-h3{font-size:1.125rem;line-height:1.33;}.md-h4{font-size:1.25rem;line-height:1.2;}.md-h5{font-size:1.5rem;line-height:1.33;}.md-h6{font-size:2rem;line-height:1.25;}.md-h7{font-size:2.625rem;line-height:1.14;}.md-h8{font-size:3.125rem;line-height:1.12;}}/*!sc*/
# @media (min-width:768px) and (max-width:1023px){.ml-h0{font-size:.75rem;line-height:1.33;}.ml-h1{font-size:.875rem;line-height:1.42;}.ml-h2{font-size:1rem;line-height:1.25;}.ml-h3{font-size:1.125rem;line-height:1.33;}.ml-h4{font-size:1.25rem;line-height:1.2;}.ml-h5{font-size:1.5rem;line-height:1.33;}.ml-h6{font-size:2rem;line-height:1.25;}.ml-h7{font-size:2.625rem;line-height:1.14;}.ml-h8{font-size:3.125rem;line-height:1.12;}}/*!sc*/
# @media (min-width:1024px){.lg-h0{font-size:.75rem;line-height:1.33;}.lg-h1{font-size:.875rem;line-height:1.42;}.lg-h2{font-size:1rem;line-height:1.25;}.lg-h3{font-size:1.125rem;line-height:1.33;}.lg-h4{font-size:1.25rem;line-height:1.2;}.lg-h5{font-size:1.5rem;line-height:1.33;}.lg-h6{font-size:2rem;line-height:1.25;}.lg-h8{font-size:3.125rem;line-height:1.12;}}/*!sc*/
# .m0{margin:0 !important;}/*!sc*/
# .mt0{margin-top:0 !important;}/*!sc*/
# .mr0{margin-right:0 !important;}/*!sc*/
# .mb0{margin-bottom:0 !important;}/*!sc*/
# .ml0,.mx0{margin-left:0 !important;}/*!sc*/
# .mx0{margin-right:0 !important;}/*!sc*/
# .my0{margin-top:0 !important;margin-bottom:0 !important;}/*!sc*/
# .m1{margin:.125rem !important;}/*!sc*/
# .mt1{margin-top:.125rem !important;}/*!sc*/
# .mr1{margin-right:.125rem !important;}/*!sc*/
# .mb1{margin-bottom:.125rem !important;}/*!sc*/
# .ml1,.mx1{margin-left:.125rem !important;}/*!sc*/
# .mx1{margin-right:.125rem !important;}/*!sc*/
# .my1{margin-top:.125rem !important;margin-bottom:.125rem !important;}/*!sc*/
# .m2{margin:.25rem !important;}/*!sc*/
# .mt2{margin-top:.25rem !important;}/*!sc*/
# .mr2{margin-right:.25rem !important;}/*!sc*/
# .mb2{margin-bottom:.25rem !important;}/*!sc*/
# .ml2,.mx2{margin-left:.25rem !important;}/*!sc*/
# .mx2{margin-right:.25rem !important;}/*!sc*/
# .my2{margin-top:.25rem !important;margin-bottom:.25rem !important;}/*!sc*/
# .m3{margin:.5rem !important;}/*!sc*/
# .mt3{margin-top:.5rem !important;}/*!sc*/
# .mr3{margin-right:.5rem !important;}/*!sc*/
# .mb3{margin-bottom:.5rem !important;}/*!sc*/
# .ml3,.mx3{margin-left:.5rem !important;}/*!sc*/
# .mx3{margin-right:.5rem !important;}/*!sc*/
# .my3{margin-top:.5rem !important;margin-bottom:.5rem !important;}/*!sc*/
# .m4{margin:1rem !important;}/*!sc*/
# .mt4{margin-top:1rem !important;}/*!sc*/
# .mr4{margin-right:1rem !important;}/*!sc*/
# .mb4{margin-bottom:1rem !important;}/*!sc*/
# .ml4,.mx4{margin-left:1rem !important;}/*!sc*/
# .mx4{margin-right:1rem !important;}/*!sc*/
# .my4{margin-top:1rem !important;margin-bottom:1rem !important;}/*!sc*/
# .m5{margin:2rem !important;}/*!sc*/
# .mt5{margin-top:2rem !important;}/*!sc*/
# .mr5{margin-right:2rem !important;}/*!sc*/
# .mb5{margin-bottom:2rem !important;}/*!sc*/
# .ml5,.mx5{margin-left:2rem !important;}/*!sc*/
# .mx5{margin-right:2rem !important;}/*!sc*/
# .my5{margin-top:2rem !important;margin-bottom:2rem !important;}/*!sc*/
# .m6{margin:4rem !important;}/*!sc*/
# .mt6{margin-top:4rem !important;}/*!sc*/
# .mr6{margin-right:4rem !important;}/*!sc*/
# .mb6{margin-bottom:4rem !important;}/*!sc*/
# .ml6,.mx6{margin-left:4rem !important;}/*!sc*/
# .mx6{margin-right:4rem !important;}/*!sc*/
# .my6{margin-top:4rem !important;margin-bottom:4rem !important;}/*!sc*/
# .m-auto{margin:auto!important;}/*!sc*/
# .mt-auto{margin-top:auto!important;}/*!sc*/
# .mr-auto{margin-right:auto!important;}/*!sc*/
# .mb-auto{margin-bottom:auto!important;}/*!sc*/
# .ml-auto,.mx-auto{margin-left:auto!important;}/*!sc*/
# .mx-auto{margin-right:auto!important;}/*!sc*/
# .my-auto{margin-top:auto!important;margin-bottom:auto!important;}/*!sc*/
# @media (min-width:640px) and (max-width:1023px){.md-m0{margin:0 !important;}.md-mt0{margin-top:0 !important;}.md-mr0{margin-right:0 !important;}.md-mb0{margin-bottom:0 !important;}.md-ml0,.md-mx0{margin-left:0 !important;}.md-mx0{margin-right:0 !important;}.md-my0{margin-top:0 !important;margin-bottom:0 !important;}.md-m1{margin:.125rem !important;}.md-mt1{margin-top:.125rem !important;}.md-mr1{margin-right:.125rem !important;}.md-mb1{margin-bottom:.125rem !important;}.md-ml1,.md-mx1{margin-left:.125rem !important;}.md-mx1{margin-right:.125rem !important;}.md-my1{margin-top:.125rem !important;margin-bottom:.125rem !important;}.md-m2{margin:.25rem !important;}.md-mt2{margin-top:.25rem !important;}.md-mr2{margin-right:.25rem !important;}.md-mb2{margin-bottom:.25rem !important;}.md-ml2,.md-mx2{margin-left:.25rem !important;}.md-mx2{margin-right:.25rem !important;}.md-my2{margin-top:.25rem !important;margin-bottom:.25rem !important;}.md-m3{margin:.5rem !important;}.md-mt3{margin-top:.5rem !important;}.md-mr3{margin-right:.5rem !important;}.md-mb3{margin-bottom:.5rem !important;}.md-ml3,.md-mx3{margin-left:.5rem !important;}.md-mx3{margin-right:.5rem !important;}.md-my3{margin-top:.5rem !important;margin-bottom:.5rem !important;}.md-m4{margin:1rem !important;}.md-mt4{margin-top:1rem !important;}.md-mr4{margin-right:1rem !important;}.md-mb4{margin-bottom:1rem !important;}.md-ml4,.md-mx4{margin-left:1rem !important;}.md-mx4{margin-right:1rem !important;}.md-my4{margin-top:1rem !important;margin-bottom:1rem !important;}.md-m5{margin:2rem !important;}.md-mt5{margin-top:2rem !important;}.md-mr5{margin-right:2rem !important;}.md-mb5{margin-bottom:2rem !important;}.md-ml5,.md-mx5{margin-left:2rem !important;}.md-mx5{margin-right:2rem !important;}.md-my5{margin-top:2rem !important;margin-bottom:2rem !important;}.md-m6{margin:4rem !important;}.md-mt6{margin-top:4rem !important;}.md-mr6{margin-right:4rem !important;}.md-mb6{margin-bottom:4rem !important;}.md-ml6,.md-mx6{margin-left:4rem !important;}.md-mx6{margin-right:4rem !important;}.md-my6{margin-top:4rem !important;margin-bottom:4rem !important;}.md-m-auto{margin:auto!important;}.md-mt-auto{margin-top:auto!important;}.md-mr-auto{margin-right:auto!important;}.md-mb-auto{margin-bottom:auto!important;}.md-ml-auto,.md-mx-auto{margin-left:auto!important;}.md-mx-auto{margin-right:auto!important;}.md-my-auto{margin-top:auto!important;margin-bottom:auto!important;}}/*!sc*/
# @media (min-width:768px) and (max-width:1023px){.ml-m0{margin:0 !important;}.ml-mt0{margin-top:0 !important;}.ml-mr0{margin-right:0 !important;}.ml-mb0{margin-bottom:0 !important;}.ml-ml0,.ml-mx0{margin-left:0 !important;}.ml-mx0{margin-right:0 !important;}.ml-my0{margin-top:0 !important;margin-bottom:0 !important;}.ml-m1{margin:.125rem !important;}.ml-mt1{margin-top:.125rem !important;}.ml-mr1{margin-right:.125rem !important;}.ml-mb1{margin-bottom:.125rem !important;}.ml-ml1,.ml-mx1{margin-left:.125rem !important;}.ml-mx1{margin-right:.125rem !important;}.ml-my1{margin-top:.125rem !important;margin-bottom:.125rem !important;}.ml-m2{margin:.25rem !important;}.ml-mt2{margin-top:.25rem !important;}.ml-mr2{margin-right:.25rem !important;}.ml-mb2{margin-bottom:.25rem !important;}.ml-ml2,.ml-mx2{margin-left:.25rem !important;}.ml-mx2{margin-right:.25rem !important;}.ml-my2{margin-top:.25rem !important;margin-bottom:.25rem !important;}.ml-m3{margin:.5rem !important;}.ml-mt3{margin-top:.5rem !important;}.ml-mr3{margin-right:.5rem !important;}.ml-mb3{margin-bottom:.5rem !important;}.ml-ml3,.ml-mx3{margin-left:.5rem !important;}.ml-mx3{margin-right:.5rem !important;}.ml-my3{margin-top:.5rem !important;margin-bottom:.5rem !important;}.ml-m4{margin:1rem !important;}.ml-mt4{margin-top:1rem !important;}.ml-mr4{margin-right:1rem !important;}.ml-mb4{margin-bottom:1rem !important;}.ml-ml4,.ml-mx4{margin-left:1rem !important;}.ml-mx4{margin-right:1rem !important;}.ml-my4{margin-top:1rem !important;margin-bottom:1rem !important;}.ml-m5{margin:2rem !important;}.ml-mt5{margin-top:2rem !important;}.ml-mr5{margin-right:2rem !important;}.ml-mb5{margin-bottom:2rem !important;}.ml-ml5,.ml-mx5{margin-left:2rem !important;}.ml-mx5{margin-right:2rem !important;}.ml-my5{margin-top:2rem !important;margin-bottom:2rem !important;}.ml-m6{margin:4rem !important;}.ml-mt6{margin-top:4rem !important;}.ml-mr6{margin-right:4rem !important;}.ml-mb6{margin-bottom:4rem !important;}.ml-ml6,.ml-mx6{margin-left:4rem !important;}.ml-mx6{margin-right:4rem !important;}.ml-my6{margin-top:4rem !important;margin-bottom:4rem !important;}.ml-m-auto{margin:auto!important;}.ml-mt-auto{margin-top:auto!important;}.ml-mr-auto{margin-right:auto!important;}.ml-mb-auto{margin-bottom:auto!important;}.ml-ml-auto,.ml-mx-auto{margin-left:auto!important;}.ml-mx-auto{margin-right:auto!important;}.ml-my-auto{margin-top:auto!important;margin-bottom:auto!important;}}/*!sc*/
# @media (min-width:1024px){.lg-m0{margin:0 !important;}.lg-mt0{margin-top:0 !important;}.lg-mr0{margin-right:0 !important;}.lg-mb0{margin-bottom:0 !important;}.lg-ml0,.lg-mx0{margin-left:0 !important;}.lg-mx0{margin-right:0 !important;}.lg-my0{margin-top:0 !important;margin-bottom:0 !important;}.lg-m1{margin:.125rem !important;}.lg-mt1{margin-top:.125rem !important;}.lg-mr1{margin-right:.125rem !important;}.lg-mb1{margin-bottom:.125rem !important;}.lg-ml1,.lg-mx1{margin-left:.125rem !important;}.lg-mx1{margin-right:.125rem !important;}.lg-my1{margin-top:.125rem !important;margin-bottom:.125rem !important;}.lg-m2{margin:.25rem !important;}.lg-mt2{margin-top:.25rem !important;}.lg-mr2{margin-right:.25rem !important;}.lg-mb2{margin-bottom:.25rem !important;}.lg-ml2,.lg-mx2{margin-left:.25rem !important;}.lg-mx2{margin-right:.25rem !important;}.lg-my2{margin-top:.25rem !important;margin-bottom:.25rem !important;}.lg-m3{margin:.5rem !important;}.lg-mt3{margin-top:.5rem !important;}.lg-mr3{margin-right:.5rem !important;}.lg-mb3{margin-bottom:.5rem !important;}.lg-ml3,.lg-mx3{margin-left:.5rem !important;}.lg-mx3{margin-right:.5rem !important;}.lg-my3{margin-top:.5rem !important;margin-bottom:.5rem !important;}.lg-m4{margin:1rem !important;}.lg-mt4{margin-top:1rem !important;}.lg-mr4{margin-right:1rem !important;}.lg-mb4{margin-bottom:1rem !important;}.lg-ml4,.lg-mx4{margin-left:1rem !important;}.lg-mx4{margin-right:1rem !important;}.lg-my4{margin-top:1rem !important;margin-bottom:1rem !important;}.lg-m5{margin:2rem !important;}.lg-mt5{margin-top:2rem !important;}.lg-mr5{margin-right:2rem !important;}.lg-mb5{margin-bottom:2rem !important;}.lg-ml5,.lg-mx5{margin-left:2rem !important;}.lg-mx5{margin-right:2rem !important;}.lg-my5{margin-top:2rem !important;margin-bottom:2rem !important;}.lg-m6{margin:4rem !important;}.lg-mt6{margin-top:4rem !important;}.lg-mr6{margin-right:4rem !important;}.lg-mb6{margin-bottom:4rem !important;}.lg-ml6,.lg-mx6{margin-left:4rem !important;}.lg-mx6{margin-right:4rem !important;}.lg-my6{margin-top:4rem !important;margin-bottom:4rem !important;}.lg-m-auto{margin:auto!important;}.lg-mt-auto{margin-top:auto!important;}.lg-mr-auto{margin-right:auto!important;}.lg-mb-auto{margin-bottom:auto!important;}.lg-ml-auto,.lg-mx-auto{margin-left:auto!important;}.lg-mx-auto{margin-right:auto!important;}.lg-my-auto{margin-top:auto!important;margin-bottom:auto!important;}}/*!sc*/
# .p0{padding:0 !important;}/*!sc*/
# .pt0{padding-top:0 !important;}/*!sc*/
# .pr0{padding-right:0 !important;}/*!sc*/
# .pb0{padding-bottom:0 !important;}/*!sc*/
# .pl0,.px0{padding-left:0 !important;}/*!sc*/
# .px0{padding-right:0 !important;}/*!sc*/
# .py0{padding-top:0 !important;padding-bottom:0 !important;}/*!sc*/
# .p1{padding:.5rem !important;}/*!sc*/
# .pt1{padding-top:.5rem !important;}/*!sc*/
# .pr1{padding-right:.5rem !important;}/*!sc*/
# .pb1{padding-bottom:.5rem !important;}/*!sc*/
# .pl1,.px1{padding-left:.5rem !important;}/*!sc*/
# .px1{padding-right:.5rem !important;}/*!sc*/
# .py1{padding-top:.5rem !important;padding-bottom:.5rem !important;}/*!sc*/
# .p2{padding:1rem !important;}/*!sc*/
# .pt2{padding-top:1rem !important;}/*!sc*/
# .pr2{padding-right:1rem !important;}/*!sc*/
# .pb2{padding-bottom:1rem !important;}/*!sc*/
# .pl2,.px2{padding-left:1rem !important;}/*!sc*/
# .px2{padding-right:1rem !important;}/*!sc*/
# .py2{padding-top:1rem !important;padding-bottom:1rem !important;}/*!sc*/
# .p3{padding:2rem !important;}/*!sc*/
# .pt3{padding-top:2rem !important;}/*!sc*/
# .pr3{padding-right:2rem !important;}/*!sc*/
# .pb3{padding-bottom:2rem !important;}/*!sc*/
# .pl3,.px3{padding-left:2rem !important;}/*!sc*/
# .px3{padding-right:2rem !important;}/*!sc*/
# .py3{padding-top:2rem !important;padding-bottom:2rem !important;}/*!sc*/
# .p4{padding:3rem !important;}/*!sc*/
# .pt4{padding-top:3rem !important;}/*!sc*/
# .pr4{padding-right:3rem !important;}/*!sc*/
# .pb4{padding-bottom:3rem !important;}/*!sc*/
# .pl4,.px4{padding-left:3rem !important;}/*!sc*/
# .px4{padding-right:3rem !important;}/*!sc*/
# .py4{padding-top:3rem !important;padding-bottom:3rem !important;}/*!sc*/
# .p5{padding:4rem !important;}/*!sc*/
# .pt5{padding-top:4rem !important;}/*!sc*/
# .pr5{padding-right:4rem !important;}/*!sc*/
# .pb5{padding-bottom:4rem !important;}/*!sc*/
# .pl5,.px5{padding-left:4rem !important;}/*!sc*/
# .px5{padding-right:4rem !important;}/*!sc*/
# .py5{padding-top:4rem !important;padding-bottom:4rem !important;}/*!sc*/
# @media (min-width:640px) and (max-width:1023px){.md-p0{padding:0 !important;}.md-pt0{padding-top:0 !important;}.md-pr0{padding-right:0 !important;}.md-pb0{padding-bottom:0 !important;}.md-pl0,.md-px0{padding-left:0 !important;}.md-px0{padding-right:0 !important;}.md-py0{padding-top:0 !important;padding-bottom:0 !important;}.md-p1{padding:.5rem !important;}.md-pt1{padding-top:.5rem !important;}.md-pr1{padding-right:.5rem !important;}.md-pb1{padding-bottom:.5rem !important;}.md-pl1,.md-px1{padding-left:.5rem !important;}.md-px1{padding-right:.5rem !important;}.md-py1{padding-top:.5rem !important;padding-bottom:.5rem !important;}.md-p2{padding:1rem !important;}.md-pt2{padding-top:1rem !important;}.md-pr2{padding-right:1rem !important;}.md-pb2{padding-bottom:1rem !important;}.md-pl2,.md-px2{padding-left:1rem !important;}.md-px2{padding-right:1rem !important;}.md-py2{padding-top:1rem !important;padding-bottom:1rem !important;}.md-p3{padding:2rem !important;}.md-pt3{padding-top:2rem !important;}.md-pr3{padding-right:2rem !important;}.md-pb3{padding-bottom:2rem !important;}.md-pl3,.md-px3{padding-left:2rem !important;}.md-px3{padding-right:2rem !important;}.md-py3{padding-top:2rem !important;padding-bottom:2rem !important;}.md-p4{padding:3rem !important;}.md-pt4{padding-top:3rem !important;}.md-pr4{padding-right:3rem !important;}.md-pb4{padding-bottom:3rem !important;}.md-pl4,.md-px4{padding-left:3rem !important;}.md-px4{padding-right:3rem !important;}.md-py4{padding-top:3rem !important;padding-bottom:3rem !important;}.md-p5{padding:4rem !important;}.md-pt5{padding-top:4rem !important;}.md-pr5{padding-right:4rem !important;}.md-pb5{padding-bottom:4rem !important;}.md-pl5,.md-px5{padding-left:4rem !important;}.md-px5{padding-right:4rem !important;}.md-py5{padding-top:4rem !important;padding-bottom:4rem !important;}}/*!sc*/
# @media (min-width:768px) and (max-width:1023px){.ml-p0{padding:0 !important;}.ml-pt0{padding-top:0 !important;}.ml-pr0{padding-right:0 !important;}.ml-pb0{padding-bottom:0 !important;}.ml-pl0,.ml-px0{padding-left:0 !important;}.ml-px0{padding-right:0 !important;}.ml-py0{padding-top:0 !important;padding-bottom:0 !important;}.ml-p1{padding:.5rem !important;}.ml-pt1{padding-top:.5rem !important;}.ml-pr1{padding-right:.5rem !important;}.ml-pb1{padding-bottom:.5rem !important;}.ml-pl1,.ml-px1{padding-left:.5rem !important;}.ml-px1{padding-right:.5rem !important;}.ml-py1{padding-top:.5rem !important;padding-bottom:.5rem !important;}.ml-p2{padding:1rem !important;}.ml-pt2{padding-top:1rem !important;}.ml-pr2{padding-right:1rem !important;}.ml-pb2{padding-bottom:1rem !important;}.ml-pl2,.ml-px2{padding-left:1rem !important;}.ml-px2{padding-right:1rem !important;}.ml-py2{padding-top:1rem !important;padding-bottom:1rem !important;}.ml-p3{padding:2rem !important;}.ml-pt3{padding-top:2rem !important;}.ml-pr3{padding-right:2rem !important;}.ml-pb3{padding-bottom:2rem !important;}.ml-pl3,.ml-px3{padding-left:2rem !important;}.ml-px3{padding-right:2rem !important;}.ml-py3{padding-top:2rem !important;padding-bottom:2rem !important;}.ml-p4{padding:3rem !important;}.ml-pt4{padding-top:3rem !important;}.ml-pr4{padding-right:3rem !important;}.ml-pb4{padding-bottom:3rem !important;}.ml-pl4,.ml-px4{padding-left:3rem !important;}.ml-px4{padding-right:3rem !important;}.ml-py4{padding-top:3rem !important;padding-bottom:3rem !important;}.ml-p5{padding:4rem !important;}.ml-pt5{padding-top:4rem !important;}.ml-pr5{padding-right:4rem !important;}.ml-pb5{padding-bottom:4rem !important;}.ml-pl5,.ml-px5{padding-left:4rem !important;}.ml-px5{padding-right:4rem !important;}.ml-py5{padding-top:4rem !important;padding-bottom:4rem !important;}}/*!sc*/
# @media (min-width:1024px){.lg-p0{padding:0 !important;}.lg-pt0{padding-top:0 !important;}.lg-pr0{padding-right:0 !important;}.lg-pb0{padding-bottom:0 !important;}.lg-pl0,.lg-px0{padding-left:0 !important;}.lg-px0{padding-right:0 !important;}.lg-py0{padding-top:0 !important;padding-bottom:0 !important;}.lg-p1{padding:.5rem !important;}.lg-pt1{padding-top:.5rem !important;}.lg-pr1{padding-right:.5rem !important;}.lg-pb1{padding-bottom:.5rem !important;}.lg-pl1,.lg-px1{padding-left:.5rem !important;}.lg-px1{padding-right:.5rem !important;}.lg-py1{padding-top:.5rem !important;padding-bottom:.5rem !important;}.lg-p2{padding:1rem !important;}.lg-pt2{padding-top:1rem !important;}.lg-pr2{padding-right:1rem !important;}.lg-pb2{padding-bottom:1rem !important;}.lg-pl2,.lg-px2{padding-left:1rem !important;}.lg-px2{padding-right:1rem !important;}.lg-py2{padding-top:1rem !important;padding-bottom:1rem !important;}.lg-p3{padding:2rem !important;}.lg-pt3{padding-top:2rem !important;}.lg-pr3{padding-right:2rem !important;}.lg-pb3{padding-bottom:2rem !important;}.lg-pl3,.lg-px3{padding-left:2rem !important;}.lg-px3{padding-right:2rem !important;}.lg-py3{padding-top:2rem !important;padding-bottom:2rem !important;}.lg-p4{padding:3rem !important;}.lg-pt4{padding-top:3rem !important;}.lg-pr4{padding-right:3rem !important;}.lg-pb4{padding-bottom:3rem !important;}.lg-pl4,.lg-px4{padding-left:3rem !important;}.lg-px4{padding-right:3rem !important;}.lg-py4{padding-top:3rem !important;padding-bottom:3rem !important;}.lg-p5{padding:4rem !important;}.lg-pt5{padding-top:4rem !important;}.lg-pr5{padding-right:4rem !important;}.lg-pb5{padding-bottom:4rem !important;}.lg-pl5,.lg-px5{padding-left:4rem !important;}.lg-px5{padding-right:4rem !important;}.lg-py5{padding-top:4rem !important;padding-bottom:4rem !important;}}/*!sc*/
# .border{border:1px solid #ccc;}/*!sc*/
# .border-none{border:0!important;}/*!sc*/
# .border-top{border-top:1px solid #ccc;}/*!sc*/
# .border-right{border-right:1px solid #ccc;}/*!sc*/
# .border-bottom{border-bottom:1px solid #ccc;}/*!sc*/
# .border-left{border-left:1px solid #ccc;}/*!sc*/
# .sticky,.sticky0{position:-webkit-sticky;position:sticky;}/*!sc*/
# .sticky0{top:0;}/*!sc*/
# .sticky1{position:-webkit-sticky;position:sticky;top:.125rem;}/*!sc*/
# .sticky2{position:-webkit-sticky;position:sticky;top:.25rem;}/*!sc*/
# .sticky3{position:-webkit-sticky;position:sticky;top:.5rem;}/*!sc*/
# .sticky4{position:-webkit-sticky;position:sticky;top:1rem;}/*!sc*/
# .sticky5{position:-webkit-sticky;position:sticky;top:2rem;}/*!sc*/
# .sticky6{position:-webkit-sticky;position:sticky;top:4rem;}/*!sc*/
# @media (min-width:640px) and (max-width:1023px){.md-sticky,.md-sticky0{position:-webkit-sticky;position:sticky;}.md-sticky0{top:0;}.md-sticky1{position:-webkit-sticky;position:sticky;top:.125rem;}.md-sticky2{position:-webkit-sticky;position:sticky;top:.25rem;}.md-sticky3{position:-webkit-sticky;position:sticky;top:.5rem;}.md-sticky4{position:-webkit-sticky;position:sticky;top:1rem;}.md-sticky5{position:-webkit-sticky;position:sticky;top:2rem;}.md-sticky6{position:-webkit-sticky;position:sticky;top:4rem;}}/*!sc*/
# @media (min-width:768px) and (max-width:1023px){.ml-sticky,.ml-sticky0{position:-webkit-sticky;position:sticky;}.ml-sticky0{top:0;}.ml-sticky1{position:-webkit-sticky;position:sticky;top:.125rem;}.ml-sticky2{position:-webkit-sticky;position:sticky;top:.25rem;}.ml-sticky3{position:-webkit-sticky;position:sticky;top:.5rem;}.ml-sticky4{position:-webkit-sticky;position:sticky;top:1rem;}.ml-sticky5{position:-webkit-sticky;position:sticky;top:2rem;}.md-sticky6{position:-webkit-sticky;position:sticky;top:4rem;}}/*!sc*/
# @media (min-width:1024px){.lg-sticky,.lg-sticky0{position:-webkit-sticky;position:sticky;}.lg-sticky0{top:0;}.lg-sticky1{position:-webkit-sticky;position:sticky;top:.125rem;}.lg-sticky2{position:-webkit-sticky;position:sticky;top:.25rem;}.lg-sticky3{position:-webkit-sticky;position:sticky;top:.5rem;}.lg-sticky4{position:-webkit-sticky;position:sticky;top:1rem;}.lg-sticky5{position:-webkit-sticky;position:sticky;top:2rem;}.lg-sticky6{position:-webkit-sticky;position:sticky;top:4rem;}}/*!sc*/
# .sticky-subnav-offset{position:-webkit-sticky;position:sticky;top:5rem;}/*!sc*/
# .content-box{box-sizing:content-box;}/*!sc*/
# :focus,a:focus,button:focus{outline-color:#1A1D26;}/*!sc*/
# data-styled.g68[id="sc-global-agjxL1"]{content:"sc-global-agjxL1,"}/*!sc*/
# .ijikNr{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;margin-left:.5rem;margin-right:.5rem;box-sizing:border-box;-webkit-flex:0 0;-ms-flex:0 0;flex:0 0;-webkit-flex-basis:calc(100% - (2 * .5rem));-ms-flex-preferred-size:calc(100% - (2 * .5rem));flex-basis:calc(100% - (2 * .5rem));max-width:calc(100% - (2 * .5rem));width:-moz-available;}/*!sc*/
# @media (min-width:640px){}/*!sc*/
# @media (min-width:768px){}/*!sc*/
# @media (min-width:1024px){.ijikNr{-webkit-flex:0 0;-ms-flex:0 0;flex:0 0;-webkit-flex-basis:calc(66.66666666666667% - (2 * .5rem));-ms-flex-preferred-size:calc(66.66666666666667% - (2 * .5rem));flex-basis:calc(66.66666666666667% - (2 * .5rem));max-width:calc(66.66666666666667% - (2 * .5rem));}}/*!sc*/
# @media (min-width:1264px){}/*!sc*/
# .hmSgcC{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;margin-left:.5rem;margin-right:.5rem;box-sizing:border-box;width:-moz-available;}/*!sc*/
# @media (min-width:640px){}/*!sc*/
# @media (min-width:768px){}/*!sc*/
# @media (min-width:1024px){.hmSgcC{-webkit-flex:0 0;-ms-flex:0 0;flex:0 0;-webkit-flex-basis:calc(33.333333333333336% - (2 * .5rem));-ms-flex-preferred-size:calc(33.333333333333336% - (2 * .5rem));flex-basis:calc(33.333333333333336% - (2 * .5rem));max-width:calc(33.333333333333336% - (2 * .5rem));}}/*!sc*/
# @media (min-width:1264px){}/*!sc*/
# .bcUcuQ{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;margin-left:.5rem;margin-right:.5rem;box-sizing:border-box;-webkit-flex:0 0;-ms-flex:0 0;flex:0 0;-webkit-flex-basis:calc(100% - (2 * .5rem));-ms-flex-preferred-size:calc(100% - (2 * .5rem));flex-basis:calc(100% - (2 * .5rem));max-width:calc(100% - (2 * .5rem));width:-moz-available;}/*!sc*/
# @media (min-width:640px){.bcUcuQ{-webkit-flex:0 0;-ms-flex:0 0;flex:0 0;-webkit-flex-basis:calc(58.333333333333336% - (2 * .5rem));-ms-flex-preferred-size:calc(58.333333333333336% - (2 * .5rem));flex-basis:calc(58.333333333333336% - (2 * .5rem));max-width:calc(58.333333333333336% - (2 * .5rem));}}/*!sc*/
# @media (min-width:768px){}/*!sc*/
# @media (min-width:1024px){.bcUcuQ{-webkit-flex:0 0;-ms-flex:0 0;flex:0 0;-webkit-flex-basis:calc(25% - (2 * .5rem));-ms-flex-preferred-size:calc(25% - (2 * .5rem));flex-basis:calc(25% - (2 * .5rem));max-width:calc(25% - (2 * .5rem));-webkit-order:1;-ms-flex-order:1;order:1;}}/*!sc*/
# @media (min-width:1264px){}/*!sc*/
# data-styled.g168[id="Cell-sc-1abjmm4-0"]{content:"ijikNr,hmSgcC,bcUcuQ,"}/*!sc*/
# @media (min-width:1024px){.kQkqKw{display:none !important;}}/*!sc*/
# @media (min-width:0) and (max-width:1023px){.fjAwZI{display:none !important;}}/*!sc*/
# @media (min-width:0) and (max-width:639px){.hWOBmI{display:none !important;}}/*!sc*/
# @media (min-width:0) and (max-width:){.hEoaXc{display:none !important;}}/*!sc*/
# @media (min-width:640px){.hBzpiJ{display:none !important;}}/*!sc*/
# data-styled.g169[id="Hide-kg09cx-0"]{content:"kQkqKw,fjAwZI,hWOBmI,hEoaXc,hBzpiJ,"}/*!sc*/
# .fQYHzS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin:0 -.5rem;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# data-styled.g171[id="Grid-lx2f3i-0"]{content:"fQYHzS,"}/*!sc*/
# .kkKJUL{padding:0 1rem;max-width:100vw;margin-left:auto;margin-right:auto;}/*!sc*/
# @media (min-width:1212px){.kkKJUL{width:1180px;box-sizing:content-box;}}/*!sc*/
# data-styled.g172[id="Content-sc-837ada-0"]{content:"kkKJUL,"}/*!sc*/
# .gyhhCp{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;margin-bottom:2rem;}/*!sc*/
# @media (min-width:1024px){.gyhhCp{margin-bottom:0rem;}}/*!sc*/
# .knONpq{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;margin-bottom:1rem;}/*!sc*/
# .ckiGVM{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;padding:2rem;}/*!sc*/
# .dWWnRo{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;}/*!sc*/
# .jXDEAj{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;padding:1rem;}/*!sc*/
# .dFTmMS{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;margin-bottom:0.25rem;}/*!sc*/
# .cWYZTG{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;margin-bottom:2rem;padding:1rem;border:1px solid #D3D7DC;}/*!sc*/
# @media (min-width:640px){.cWYZTG{margin-bottom:1rem;}}/*!sc*/
# @media (min-width:1024px){.cWYZTG{margin-bottom:0rem;}}/*!sc*/
# .hTnNtV{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;margin-bottom:2rem;}/*!sc*/
# @media (min-width:640px){.hTnNtV{margin-bottom:1rem;}}/*!sc*/
# @media (min-width:1024px){.hTnNtV{margin-bottom:0rem;}}/*!sc*/
# .erkdnc{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;margin-bottom:0.5rem;}/*!sc*/
# @media (min-width:1024px){.erkdnc{margin-bottom:0rem;}}/*!sc*/
# .iZCosX{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;margin-bottom:0.5rem;padding:1rem;border:1px solid #D3D7DC;}/*!sc*/
# @media (min-width:1024px){.iZCosX{margin-bottom:0rem;}}/*!sc*/
# .kmHbOk{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;margin-bottom:0.5rem;}/*!sc*/
# @media (min-width:1024px){.kmHbOk{margin-bottom:0rem;}}/*!sc*/
# @media (min-width:1024px){.kmHbOk{padding:1rem;}}/*!sc*/
# .ecdieg{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;margin-bottom:0.5rem;}/*!sc*/
# .dZMRhA{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;}/*!sc*/
# @media (min-width:1024px){.dZMRhA{padding:1rem;}}/*!sc*/
# .eLivRJ{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;margin-bottom:2rem;}/*!sc*/
# .MDPXU{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;margin-bottom:0.5rem;border:1px solid #D3D7DC;}/*!sc*/
# .zgHow{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;border-right:1px solid #D3D7DC;}/*!sc*/
# .jFoOVF{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;padding:0.5rem;}/*!sc*/
# .iTVRyo{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;}/*!sc*/
# @media (min-width:1024px){.iTVRyo{margin-bottom:4rem;}}/*!sc*/
# .bMEgtT{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;margin-bottom:4rem;}/*!sc*/
# .dJhfFE{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;margin-bottom:1rem;}/*!sc*/
# @media (min-width:640px){.dJhfFE{margin-bottom:2rem;}}/*!sc*/
# @media (min-width:1024px){.dJhfFE{margin-bottom:1rem;}}/*!sc*/
# .UgQtc{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;border:1px solid #D3D7DC;}/*!sc*/
# .iETkGn{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;margin-bottom:0rem;}/*!sc*/
# .hcnnfE{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;margin-bottom:0.5rem;border-bottom:1px solid #D3D7DC;}/*!sc*/
# .ZUkgD{box-sizing:border-box;font-family:Roboto,"Helvetica Neue",Helvetica,sans-serif;padding:1rem;border:1px solid #D3D7DC;}/*!sc*/
# data-styled.g174[id="Box-w0dun1-0"]{content:"gyhhCp,knONpq,ckiGVM,dWWnRo,jXDEAj,dFTmMS,cWYZTG,hTnNtV,erkdnc,iZCosX,kmHbOk,ecdieg,dZMRhA,eLivRJ,MDPXU,zgHow,jFoOVF,iTVRyo,bMEgtT,dJhfFE,UgQtc,iETkGn,hcnnfE,ZUkgD,"}/*!sc*/
# .dxmHQv{margin:0;padding:0;font-size:1rem;line-height:1.25;font-weight:700;text-transform:uppercase;-webkit-letter-spacing:1.25px;-moz-letter-spacing:1.25px;-ms-letter-spacing:1.25px;letter-spacing:1.25px;font-family:var(--font-primary);margin-bottom:0.5rem;}/*!sc*/
# .dxmHQv > small{font-size:90%;margin-left:0.5rem;}/*!sc*/
# .dxmHQv a{color:inherit;-webkit-text-decoration:none;text-decoration:none;-webkit-transition:color 200ms;transition:color 200ms;}/*!sc*/
# .dxmHQv a:hover{color:var(--muted);}/*!sc*/
# .dxmHQv a:focus-visible{color:var(--muted);}/*!sc*/
# .vRzNE{margin:0;padding:0;font-size:2rem;line-height:1.25;font-weight:700;color:#ffffff;font-family:var(--font-secondary);margin-bottom:1rem;text-shadow:0 1px 2px rgba(0,0,0,.5);}/*!sc*/
# .vRzNE a,a.vRzNE{-webkit-transition:color 0.5s ease;transition:color 0.5s ease;}/*!sc*/
# .vRzNE a:focus,a.vRzNE:focus,.vRzNE a:hover,a.vRzNE:hover,.vRzNE a:active,a.vRzNE:active,.vRzNE a.active,a.vRzNE.active{color:#D3D7DC!important;}/*!sc*/
# .vRzNE > small{font-size:75%;margin-left:0.5rem;}/*!sc*/
# .vRzNE a{color:inherit;-webkit-text-decoration:none;text-decoration:none;-webkit-transition:color 200ms;transition:color 200ms;}/*!sc*/
# .vRzNE a:hover{color:var(--muted);}/*!sc*/
# .vRzNE a:focus-visible{color:var(--muted);}/*!sc*/
# .cyfevJ{margin:0;padding:0;font-size:0.75rem;line-height:1.33;font-weight:700;text-transform:uppercase;-webkit-letter-spacing:1.25px;-moz-letter-spacing:1.25px;-ms-letter-spacing:1.25px;letter-spacing:1.25px;font-family:var(--font-primary);margin-bottom:0.5rem;}/*!sc*/
# .cyfevJ > small{font-size:90%;margin-left:0.5rem;}/*!sc*/
# .cyfevJ a{color:inherit;-webkit-text-decoration:none;text-decoration:none;-webkit-transition:color 200ms;transition:color 200ms;}/*!sc*/
# .cyfevJ a:hover{color:var(--muted);}/*!sc*/
# .cyfevJ a:focus-visible{color:var(--muted);}/*!sc*/
# .jYjPRl{margin:0;padding:0;font-size:1.25rem;line-height:1.2;font-weight:700;font-family:var(--font-secondary);margin-bottom:0.5rem;color:var(--white-00);}/*!sc*/
# .jYjPRl > small{font-size:90%;margin-left:0.5rem;}/*!sc*/
# .jYjPRl a{color:inherit;-webkit-text-decoration:none;text-decoration:none;-webkit-transition:color 200ms;transition:color 200ms;}/*!sc*/
# .jYjPRl a:hover{color:var(--muted);}/*!sc*/
# .jYjPRl a:focus-visible{color:var(--muted);}/*!sc*/
# .MRvpF{margin:0;padding:0;font-size:1rem;line-height:1.25;font-weight:700;font-family:var(--font-secondary);margin-bottom:0.5rem;}/*!sc*/
# .MRvpF > small{font-size:90%;margin-left:0.5rem;}/*!sc*/
# .MRvpF a{color:inherit;-webkit-text-decoration:none;text-decoration:none;-webkit-transition:color 200ms;transition:color 200ms;}/*!sc*/
# @media (min-width:1024px){.MRvpF{font-size:1.25rem;line-height:1.2;}.MRvpF > small{font-size:90%;}}/*!sc*/
# .MRvpF a:hover{color:var(--muted);}/*!sc*/
# .MRvpF a:focus-visible{color:var(--muted);}/*!sc*/
# .dUZQRB{margin:0;padding:0;font-size:1.125rem;line-height:1.33;font-weight:700;text-transform:uppercase;-webkit-letter-spacing:1.25px;-moz-letter-spacing:1.25px;-ms-letter-spacing:1.25px;letter-spacing:1.25px;font-family:var(--font-secondary);margin-bottom:1rem;border-top:3px solid transparent;border-image:linear-gradient( to right, var(--red-50) 0, var(--red-50) 55px, transparent 55px );border-left:0;border-bottom:0;border-image-slice:1;padding-top:2px;}/*!sc*/
# .dUZQRB > small{font-size:90%;margin-left:0.5rem;}/*!sc*/
# .dUZQRB a{color:inherit;-webkit-text-decoration:none;text-decoration:none;-webkit-transition:color 200ms;transition:color 200ms;}/*!sc*/
# .dUZQRB a:hover{color:var(--muted);}/*!sc*/
# .dUZQRB a:focus-visible{color:var(--muted);}/*!sc*/
# .dWAZTV{margin:0;padding:0;font-size:1.125rem;line-height:1.33;font-weight:700;font-family:var(--font-secondary);margin-bottom:0rem;}/*!sc*/
# .dWAZTV > small{font-size:90%;margin-left:0.5rem;}/*!sc*/
# .dWAZTV a{color:inherit;-webkit-text-decoration:none;text-decoration:none;-webkit-transition:color 200ms;transition:color 200ms;}/*!sc*/
# @media (min-width:1024px){.dWAZTV{font-size:1rem;line-height:1.25;}.dWAZTV > small{font-size:90%;}}/*!sc*/
# .dWAZTV a:hover{color:var(--muted);}/*!sc*/
# .dWAZTV a:focus-visible{color:var(--muted);}/*!sc*/
# .gLuLXj{margin:0;padding:0;font-size:1.5rem;line-height:1.33;font-weight:400;font-family:var(--font-secondary);margin-bottom:0.5rem;}/*!sc*/
# .gLuLXj > small{font-size:75%;margin-left:0.5rem;}/*!sc*/
# .gLuLXj a{color:inherit;-webkit-text-decoration:none;text-decoration:none;-webkit-transition:color 200ms;transition:color 200ms;}/*!sc*/
# .gLuLXj a:hover{color:var(--muted);}/*!sc*/
# .gLuLXj a:focus-visible{color:var(--muted);}/*!sc*/
# .hPzcpQ{margin:0;padding:0;font-size:1.5rem;line-height:1.33;font-weight:400;font-family:var(--font-secondary);margin-bottom:0rem;}/*!sc*/
# .hPzcpQ > small{font-size:75%;margin-left:0.5rem;}/*!sc*/
# .hPzcpQ a{color:inherit;-webkit-text-decoration:none;text-decoration:none;-webkit-transition:color 200ms;transition:color 200ms;}/*!sc*/
# .hPzcpQ a:hover{color:var(--muted);}/*!sc*/
# .hPzcpQ a:focus-visible{color:var(--muted);}/*!sc*/
# .ctIhvB{margin:0;padding:0;font-size:0.875rem;line-height:1.42;font-weight:700;font-family:var(--font-secondary);margin-bottom:0.5rem;}/*!sc*/
# .ctIhvB > small{font-size:90%;margin-left:0.5rem;}/*!sc*/
# .ctIhvB a{color:inherit;-webkit-text-decoration:none;text-decoration:none;-webkit-transition:color 200ms;transition:color 200ms;}/*!sc*/
# ...
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="Content-sc-837ada-0 kkKJUL lg-hide content">
#        <div class="Links__LinksWrapper-sc-1vd0nbr-3 gSoJRm">
#         <div class="Links__Container-sc-1vd0nbr-0 eQltFd footer-link-container">
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://www.usnews.com/news">
#             News
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://bestlawfirms.usnews.com">
#             Law Firms
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://www.usnews.com/education">
#             Education
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://www.usnews.com/rankings">
#             Rankings
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://health.usnews.com/">
#             Health
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://money.usnews.com/">
#             Money
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://realestate.usnews.com/">
#             Real Estate
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://cars.usnews.com/cars-trucks">
#             Cars
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://travel.usnews.com/">
#             Travel
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://www.usnews.com/360-reviews">
#             360 Reviews
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://deals.usnews.com/">
#             Deals
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://www.usnews.com/insurance">
#             Insurance
#            </a>
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="Divider__HorizontalRule-xr0ge4-0 gFPwwu" color="#3F4451" spacing="0">
#       </div>
#       <div class="Content-sc-837ada-0 kkKJUL content">
#        <div class="Info__Container-sc-1vdhah7-0 grQneG">
#         <a href="https://www.usnews.com">
#          <img alt="U.S. News &amp; World Report" class="mb4 lg-mb0" height="40px" src="https://www.usnews.com/static/img/usn-logo-large.svg" width="160px"/>
#         </a>
#         <div class="Info__Grow-sc-1vdhah7-1 eFGqdH">
#          <div class="Info__Left-sc-1vdhah7-3 jXuJkM">
#           <div class="Info__Links-sc-1vdhah7-5 elzsCr" spacing="3">
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="https://www.usnews.com/info/features/about-usnews">
#              About
#              <span class="sm-hide md-hide">
#               U.S. News
#              </span>
#             </a>
#            </div>
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="https://www.usnews.com/about-us/editorial-guidelines">
#              Editorial Guidelines
#             </a>
#            </div>
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="https://www.usnews.com/info/features/contact">
#              Contact
#             </a>
#            </div>
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="https://www.usnews.com/info/blogs/press-room">
#              Press
#             </a>
#            </div>
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="https://mediakit.usnews.com">
#              Advertise
#             </a>
#            </div>
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="http://emailprefs.usnews.com/emailprefs/newsletters-index">
#              Newsletters
#             </a>
#            </div>
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="https://www.usnews.com/info/features/employment">
#              Jobs
#             </a>
#            </div>
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="https://www.usnews.com/info/features/sitemap">
#              Site Map
#             </a>
#            </div>
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="https://www.usnews.com/products/features/home?src=usnfooter">
#              Store
#             </a>
#            </div>
#           </div>
#           <div class="SocialIcons__Container-sc-18livsa-0 icFFld Info__FooterIcons-sc-1vdhah7-2 dhgryP mb5 lg-mb4 lg-hide">
#            <a aria-label="U.S. News &amp; World Report Facebook page" href="https://www.facebook.com/usnewsandworldreport" rel="noopener" target="_blank">
#             <svg class="Icon-sc-9wq8ul-0 SocialIcons__Facebook-sc-18livsa-1 hiHdJZ hSdiep" fill="white" height="1.5rem" role="img" width="1.5rem">
#              <use filter="0" xlink:href="#facebook">
#              </use>
#             </svg>
#            </a>
#            <a aria-label="U.S. News &amp; World Report Twitter page" href="https://twitter.com/usnews" rel="noopener" target="_blank">
#             <svg class="Icon-sc-9wq8ul-0 SocialIcons__Twitter-sc-18livsa-2 hiHdJZ fBiLxn" fill="white" height="1.5rem" role="img" width="1.5rem">
#              <use filter="0" xlink:href="#twitter">
#              </use>
#             </svg>
#            </a>
#           </div>
#           <div class="Info__Bottom-sc-1vdhah7-8 dmmajP">
#            <span class="Span-sc-19wk4id-0 Info__Copyright-sc-1vdhah7-9 lnnsuc jAudCl" size="2">
#             Copyright
#             <!-- -->
#             2023
#             <!-- -->
#             © U.S. News &amp; World Report L.P.
#            </span>
#            <span class="Span-sc-19wk4id-0 Info__Terms-sc-1vdhah7-10 lnnsuc fXTuRU" size="2">
#             <a class="Anchor-byh49a-0 PlBer" href="https://www.usnews.com/info/features/terms">
#              Terms &amp; Conditions
#             </a>
#             /
#             <a class="Anchor-byh49a-0 PlBer" href="https://www.usnews.com/features/info/privacy">
#              Privacy Policy
#             </a>
#             /
#             <a class="Anchor-byh49a-0 PlBer" href="https://www.usnews.com/features/info/privacy/ccpa">
#              California Privacy Notice
#             </a>
#             /
#             <a class="Anchor-byh49a-0 PlBer" href="https://www.usnews.com/features/info/privacy/ccpa/do-not-sell">
#              California Do Not Sell My Personal Information Request
#             </a>
#            </span>
#           </div>
#          </div>
#          <div class="Info__Right-sc-1vdhah7-4 fzQSBo sm-hide md-hide">
#           <div class="SocialIcons__Container-sc-18livsa-0 icFFld mb5 lg-mb2">
#            <a aria-label="U.S. News &amp; World Report Facebook page" href="https://www.facebook.com/usnewsandworldreport" rel="noopener" target="_blank">
#             <svg class="Icon-sc-9wq8ul-0 SocialIcons__Facebook-sc-18livsa-1 hiHdJZ hSdiep" fill="white" height="1.5rem" role="img" width="1.5rem">
#              <use filter="0" xlink:href="#facebook">
#              </use>
#             </svg>
#            </a>
#            <a aria-label="U.S. News &amp; World Report Twitter page" href="https://twitter.com/usnews" rel="noopener" target="_blank">
#             <svg class="Icon-sc-9wq8ul-0 SocialIcons__Twitter-sc-18livsa-2 hiHdJZ fBiLxn" fill="white" height="1.5rem" role="img" width="1.5rem">
#              <use filter="0" xlink:href="#twitter">
#              </use>
#             </svg>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </footer>
#     </react-trigger>
#    </div>
#    <div class="overlay__Container-sc-1mwbfqy-0 eJAyFO">
#    </div>
#    <react-trigger trigger="false">
#    </react-trigger>
#   </main>
#   <div id="footer-spacer">
#   </div>
#   <script>
#    window.__SERVER_STATE__ = {"page":"containers\u002Fpages\u002Fbrightspot\u002Fhomepage\u002Findex.js"};
#                 window.__CUSTOM_ELEMENTS__ = ["src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js"];
#                 window.__DEFER_REACT__ = false;
#                 window['__PAGE_CONTEXT_QUERY_STATE__'] = {"src\u002Fcomponents\u002Futil\u002FGlobalHelmet.js":{"data":{"meta_tags":[{"name":"brightspot.contentId","content":"0000015e-77a8-da21-a15f-ffed9f560000"},{"property":"og:title","content":"U.S. News & World Report: News, Rankings and Analysis on Politics, Education, Healthcare and More"},{"property":"og:description","content":"US News is a recognized leader in college, grad school, hospital, mutual fund, and car rankings.  Track elected officials, research health conditions, and find news you can use in politics, business, health, and education."},{"property":"twitter:title","content":"U.S. News & World Report: News, Rankings and Analysis on Politics, Education, Healthcare and More"},{"property":"twitter:description","content":"US News is a recognized leader in college, grad school, hospital, mutual fund, and car rankings.  Track elected officials, research health conditions, and find news you can use in politics, business, health, and education."},{"property":"twitter:site","content":"@USNews"},{"property":"twitter:card","content":"summary"}],"utag_data":{"site_portal":"null","site_product_subsection":"","content_type":"editorial","page_type":"sectionfront","site_product_section":"","site_product":"","site_vertical":"Homepage","stitial_fact":"The average amount of student loan debt is $29,400.","page_container":"containers\u002Fpages\u002Fbrightspot\u002Fhomepage\u002Findex.js"},"settings":{"vwo":{"patterns":["money.usnews.com\\\u002Fcredit-cards.*","travel.usnews.com\\\u002F$","\u002Fcruises\u002Fbest-cruise-lines-for-families\u002F","money.usnews.com\\\u002Finvesting\\\u002Fstocks\\\u002F(?!search)[a-z\\-]*(\\\u002Fvitals)?","money.usnews.com\\\u002Ffunds\\\u002Fetfs\\\u002F[a-z\\-]+\\\u002F[a-z0-9\\-]+\\\u002F[a-z\\-]+$","money.usnews.com\\\u002Fbanking\\\u002F*","money.usnews.com\\\u002Ffunds\\\u002Fmutual-funds\\\u002F[a-z0-9\\-]*\\\u002F[a-z0-9\\-]*\\\u002F[a-z\\-]*","money.usnews.com\u002Ffinancial-advisors","money.usnews.com\\\u002Floans.*","loans.usnews.com\\\u002F(personal|debt-consolidation|bad-credit|debt-settlement-companies|mortgage-lenders|home-equity-lenders|mortgage-refinance-lenders|va-loans|fha-loans|home-improvement-loans|mortgage-with-no-down-payment|5-1-arm-loans|reverse-mortgage|student-loans-consolidation-refinancing|student-loans|student-loans-without-co-signer|small-business|business-loans-for-bad-credit|unsecured-business-loans)","https:\u002F\u002Floans.usnews.com\\\u002Freviews\\\u002F*","https:\\\u002F\\\u002Fmoney.usnews.com\\\u002Finvesting\\\u002F[a-z0-9\\-]*\\\u002F(slideshows|articles)\\\u002F[a-z0-9\\-]*","https:\\\u002F\\\u002Fmoney.usnews.com\\\u002Finvesting\\\u002F(slideshows|articles)\\\u002F[a-z0-9\\-]*\\\u002F[a-z0-9\\-]*","https:\u002F\u002Fmoney.usnews.com\u002Finvesting\u002Farticles\u002F2016-03-10\u002F8-things-to-consider-when-buying-investment-property","money\\.usnews\\.com\\\u002Fmoney\\\u002Fretirement\\\u002F[a-z0-9\\-]*\\\u002Farticles\\\u002F[a-z0-9\\-]*\\\u002F.+","money\\.usnews\\.com\\\u002Fmoney\\\u002Fretirement\\\u002F[a-z0-9\\-]*\\\u002Farticles\\\u002F.+","money\\.usnews\\.com\\\u002Fmoney\\\u002Fpersonal-finance\\\u002F[a-z0-9\\-]*\\\u002Farticles\u002F.+","money\\.usnews\\.com\\\u002Fmoney\\\u002Fpersonal-finance\\\u002F[a-z0-9\\-]*\\\u002Farticles\u002F[a-z0-9\\-]*\\\u002F.+","money\\.usnews\\.com\\\u002Fmoney\\\u002Fblogs\\\u002Fmy-money\\\u002Farticles\\\u002F.+","money\\.usnews\\.com\\\u002Fmoney\\\u002Fblogs\\\u002Fmy-money\\\u002F[0-9]*\\\u002F[0-9]*\\\u002F[0-9]*\\\u002F.+","money\\.usnews\\.com\\\u002Fmoney\\\u002Fblogs\\\u002Fthe-smarter-mutual-fund-investor\\\u002Farticles\\\u002F*","health.usnews.com\u002Fbest-nursing-homes\u002Fsearch","health.usnews.com\u002Fbest-nursing-homes\u002Farea","\\\u002Feducation\\\u002F[a-z0-9\\\u002F\\-]*\\\u002Farticles\\\u002F[a-z0-9\\\u002F\\-]*","https:\u002F\u002Fhealth.usnews.com\u002Fmedicare\u002F","^(secure|www).usnews.com\u002Fcommerce\u002Fsignup.*"," ...
#   </script>
#   <!-- %CSS_REGRESSION_TESTING_SCRIPT_PLACEHOLDER% -->
#   <noscript>
#    <img src="https://www.usnews.com/akam/13/pixel_2adb99ee?a=dD0zZGFhNjFmMjg4NjUwZjgxYjk5OWMyYTM2MTc0ODc5ODU0ZjRiMjdmJmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;"/>
#   </noscript>
#   <script src="/3HJ_2nL42Jf1/ft/3-HQXwGVXi/iO7krDpLOD/WHU-X10B/P2ZgEiYG/aAs" type="text/javascript">
#   </script>
#  </body>
# </html>

# %% [markdown]
# 7. "finds" its current "Top Stories" (do not hard-code it's URL!) (You may use your browser's dev tools to find a functioning way to access all the "Top Stories" and then implement the access to them in your code.)

# %%
def main():
	try:
		url= "https://www.usnews.com/"
		my_headers = {'User-Agent': 'Mozilla/5.0'}
		page = requests.get(url, headers=my_headers)
		# Create a beautifulsoup object
		soup = BeautifulSoup(page.text, 'lxml')
		# find <p> that immediately follows <div> of class "col-md-6.
		list_of_contents = soup.select("div.Box-w0dun1-0.ArmRestTopStories__Part-s0vo7p-1.erkdnc.biVKSR h3.Heading-sc-1w5xk2o-0.ContentBox__StoryHeading-sc-1egb8dt-3.MRvpF.fqJuKa.story-headline > a[href]")
		# list_of_contents_2 = soup.select("div.Box-w0dun1-0.MediaLink__Content-sc-4j1zsn-0.dWWnRo.cJCmtT p.Paragraph-sc-1iyax29-0.gHMBuC")
		# prints the HTML content to the screen (almost only text here
		# just need to replaces "&nbsp;" with " ")
		for i in list_of_contents:
			a = i.text
			print(i.text)
		
		# for i in list_of_contents_2:
		#	b = i.text
		#	print(i.text)
		
		return a
	except:
		print("Problem with the connection...")

if __name__ == '__main__':
	main()
# Out:
# McCarthy, Biden to Talk Amid Debt Threat
# Existing Homes Fall 1.5% in December

# %% [markdown]
# 8. read + print the URL of the _second_ current top story to the screen (terminal)

# %%
url_list = []
def main():
	try:
		url= "https://www.usnews.com/"
		my_headers = {'User-Agent': 'Mozilla/5.0'}
		page = requests.get(url, headers=my_headers)
		# Create a beautifulsoup object
		soup = BeautifulSoup(page.text, 'lxml')
		# find <p> that immediately follows <div> of class "col-md-6.
		list_of_contents = soup.select("div.Box-w0dun1-0.ArmRestTopStories__Part-s0vo7p-1.erkdnc.biVKSR h3.Heading-sc-1w5xk2o-0.ContentBox__StoryHeading-sc-1egb8dt-3.MRvpF.fqJuKa.story-headline > a[href]")
		# prints the HTML content to the screen (almost only text here
		# just need to replaces "&nbsp;" with " ")
		for link in list_of_contents:
			tags = soup.find_all("a")
			data = link.get('href')
			url_list.append(data)
	except:
		print("Problem with the connection...")

if __name__ == '__main__':
	main()

print(url_list[1])
# Out:
# https://www.usnews.com/news/economy/articles/2023-01-20/existing-homes-fall-1-5-in-december-marking-11th-month-of-declines

# %% [markdown]
# 9. load that page

# %%
my_headers = {'User-Agent': 'Mozilla/5.0'}
url = requests.get(url_list[1], headers=my_headers) 
soup = BeautifulSoup(url.content) 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- component="containers/pages/brightspot/article-rail.js" -->
# <!-- build="static-atlas-master 1354" -->
# <html lang="en">
#  <head>
#   <link href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@300;400;500;700&amp;family=Montserrat:wght@400;600;700&amp;display=fallback" rel="stylesheet"/>
#   <title data-rh="true">
#    Existing Homes Fall 1.5% in December, Marking 11th Month of Declines | Economy | U.S. News
#   </title>
#   <meta charset="utf-8" data-rh="true"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" data-rh="true" name="viewport"/>
#   <meta content="The performance was better than expected and prices inched up a little from a year ago." data-rh="true" name="description"/>
#   <meta content="Tim Smart,economy,housing,housing market,picks,Economy,National News" data-rh="true" name="keywords"/>
#   <meta content="news" data-rh="true" name="site"/>
#   <meta content="home/articles" data-rh="true" name="zone"/>
#   <meta content="max-image-preview:large" data-rh="true" name="robots"/>
#   <meta content="5834919267" data-rh="true" property="fb:pages"/>
#   <meta content="00000185-cfd1-de18-a7bf-fff139c50000" data-rh="true" name="brightspot.contentId"/>
#   <meta content="US News &amp; World Report" data-rh="true" property="og:site_name"/>
#   <meta content="Existing Homes Fall 1.5% in December, Marking 11th Month of Declines" data-rh="true" property="og:title"/>
#   <meta content="The performance was better than expected and prices inched up a little from a year ago." data-rh="true" property="og:description"/>
#   <meta content="//www.usnews.com/news/economy/articles/2023-01-20/existing-homes-fall-1-5-in-december-marking-11th-month-of-declines" data-rh="true" property="og:url"/>
#   <meta content="https://www.usnews.com/dims4/USNEWS/29bc898/2147483647/thumbnail/970x647/quality/85/?url=https%3A%2F%2Fwww.usnews.com%2Fcmsmedia%2Fb0%2F51%2F0dfcff14480db32e15ee949e8507%2Fgettyimages-1457475362.jpg" data-rh="true" property="og:image"/>
#   <meta content="https://www.usnews.com/dims4/USNEWS/29bc898/2147483647/thumbnail/970x647/quality/85/?url=https%3A%2F%2Fwww.usnews.com%2Fcmsmedia%2Fb0%2F51%2F0dfcff14480db32e15ee949e8507%2Fgettyimages-1457475362.jpg" data-rh="true" property="og:image:secure_url"/>
#   <meta content="https://www.usnews.com/dims4/USNEWS/29bc898/2147483647/thumbnail/970x647/quality/85/?url=https%3A%2F%2Fwww.usnews.com%2Fcmsmedia%2Fb0%2F51%2F0dfcff14480db32e15ee949e8507%2Fgettyimages-1457475362.jpg" data-rh="true" property="twitter:image"/>
#   <meta content="article" data-rh="true" property="og:type"/>
#   <meta content="US News &amp; World Report" data-rh="true" property="og:site_name"/>
#   <meta content="https://www.usnews.com/news/economy/articles/2023-01-20/existing-homes-fall-1-5-in-december-marking-11th-month-of-declines" data-rh="true" property="og:url"/>
#   <meta content="summary_large_image" data-rh="true" name="twitter:card"/>
#   <meta content="@USNews" data-rh="true" name="twitter:site"/>
#   <meta content="Existing Homes Fall 1.5% in December, Marking 11th Month of Declines" data-rh="true" name="twitter:title"/>
#   <meta content="The performance was better than expected and prices inched up a little from a year ago." data-rh="true" name="twitter:description"/>
#   <meta content="owJBuFHD3VHcTSsnPSOYizmUcs3GSBjbx09vBbBi1MM" data-rh="true" name="google-site-verification"/>
#   <meta content="A8E47FA91124063A4A9C78AD5273DC0F" data-rh="true" name="msvalidate.01"/>
#   <meta content="130063997038366" data-rh="true" property="fb:app_id"/>
#   <meta content="2023-01-20T10:44Z" data-rh="true" property="sailthru.date"/>
#   <meta content="Tim Smart" data-rh="true" property="sailthru.author"/>
#   <meta content="Civic" data-rh="true" property="sailthru.site_portal"/>
#   <meta content="The performance was better than expected and prices inched up a little from a year ago." data-rh="true" property="sailthru.description"/>
#   <meta content="Existing Homes Fall 1.5% in December, Marking 11th Month of Declines" data-rh="true" property="sailthru.title"/>
#   <meta content="News" data-rh="true" property="sailthru.vertical"/>
#   <meta content="News" data-rh="true" property="vertical"/>
#   <meta content="https://www.usnews.com/dims4/USNEWS/29bc898/2147483647/thumbnail/970x647/quality/85/?url=https%3A%2F%2Fwww.usnews.com%2Fcmsmedia%2Fb0%2F51%2F0dfcff14480db32e15ee949e8507%2Fgettyimages-1457475362.jpg" data-rh="true" property="sailthru.image.full"/>
#   <meta content="economy,housing,housing-market,picks" data-rh="true" property="sailthru.tags"/>
#   <meta content="Sales of existing homes slid 1.5% in December, somewhat better than expected but the 11th straight month of decline, the National Association of Realtors said on Friday. The number was better than estimates of a 3.4% drop and brings the annual rate of home sales just a hair above 4 million. Sales ..." data-rh="true" property="preview"/>
#   <meta content="Optimizely is supported by this application but is not enabled for this page." data-rh="true" property="optimizely"/>
#   <script data-rh="true">
#    window.usnFirstByteTime = new Date();
#         performance && performance.mark && performance.mark('ttfb');
#   </script>
#   <script data-rh="true" type="text/javascript">
#    var utag_data = {"bucket_tags":["picks","economy","national-news"],"article_byline":"Tim Smart","page_type":"article","site_product_section":"Article","site_product":"Economy","article_embedded_gallery":"true","suppress_img_flag":false,"site_portal":"Civic","primary_tag":"economy","article_publish_date":"2023-01-20","site_product_subsection":"","product_ids":["firefly-00000185-cfd1-de18-a7bf-fff139c50000"],"content_type":"editorial","article_enhancements":["gallery"],"page_name":"Existing Homes Fall 1.5% in December, Marking 11th Month of Declines | Economy | U.S. News","site_vertical":"News","byline_type":"Staff Writer","article_template":"article-rail","stitial_fact":"Maine has the lowest paid governor in the country, earning $70,000 annually.","page_container":"containers/pages/brightspot/article-rail.js","tealium_environment":"prod","site_version":"atlas"};
#         (function() {
#             function usnRandId() {return (new Date().getTime() % 100000000000 + Math.random()).toString().replace(".", "");}
#             function get(name) {return (("; " + document.cookie).split("; " + name + "=")[1] || "").split(";")[0];}
#             function cookie(name, val) {return name + "=" + val + "; path=/; domain=.usnews.com";}
#             function permacookie(name, val) {var d = new Date();d.setTime(d.getTime() + 365 * 24 * 60 * 60 * 1000);return cookie(name, val) + "; expires=" + d.toUTCString();}
#             window.usn_permacookie = permacookie;
#             var usn_pageview_id = usnRandId();
#             var usn_session_id = get("usn_session_id");
#             if (!usn_session_id) {
#                 usn_session_id = usnRandId();
#                 document.cookie = cookie("usn_session_id", usn_session_id);
#             }
#             var usn_visitor_id = get("usn_visitor_id");
#             if (!usn_visitor_id) {
#                 // This should always be set by Akamai, but if not, fake it here.
#                 usn_visitor_id = usnRandId();
#                 document.cookie = permacookie("usn_visitor_id", usn_visitor_id);
#             }
#             var usn_src = get("usn_src");
#             var query = window.location.search && window.location.search.substr(1).split('&');
#             if (query) {
#                 var pair;
#                 while (pair = query.pop()) {
#                     if (pair.indexOf("src=") === 0) {
#                         var src = pair.substr(4);
#                         usn_src = usn_src || src;
#                         if (usn_src.indexOf(src) === -1) {
#                             usn_src += ',' + src;
#                         }
#                         document.cookie = permacookie("usn_src", usn_src);
#                     }
#                 }
#             }
#             var vertical = utag_data.site_vertical && utag_data.site_vertical.toLowerCase();
#             if (vertical && vertical !== 'generic') {
#                 document.cookie = cookie("cogv", vertical);
#             }
#             utag_data.usn_src = usn_src;
#             utag_data.usn_pageview_id = usn_pageview_id;
#             utag_data.usn_hit_id = usnRandId();
#             utag_data.usn_session_id = usn_session_id;
#             utag_data.usn_visitor_id = usn_visitor_id;
#
#             function identify_utag_data() {
#                 var awsCognitoEmail = get("coge");
#
#                 if (awsCognitoEmail) {
#                     // Sanitize email address
#                     awsCognitoEmail = awsCognitoEmail.trim().toLowerCase();
#                 }
#
#                 utag_data.aws_cognito_sub = get("cogsub");
#                 utag_data.aws_cognito_email = awsCognitoEmail;
#                 utag_data.sailthru_email_hashed = get("usn_sailthru_hash");
#             }
#
#             identify_utag_data();
#             window.usn_identify_utag_data = identify_utag_data;
#
#             // Global Privacy Control is not supported by many browsers but legally required to respond to
#             if (typeof(navigator) !== 'undefined' && navigator.globalPrivacyControl) {
#                 document.cookie = permacookie("usprivacy", "1YYY");
#             }
#         }());
#   </script>
#   <script data-rh="true" type="application/ld+json">
#    {"image":{"@type":"ImageObject","width":"970","url":"https://www.usnews.com/dims4/USNEWS/29bc898/2147483647/thumbnail/970x647/quality/85/?url=https%3A%2F%2Fwww.usnews.com%2Fcmsmedia%2Fb0%2F51%2F0dfcff14480db32e15ee949e8507%2Fgettyimages-1457475362.jpg","height":"647"},"wordCount":400,"keywords":["Tim Smart","economy","housing","housing market","picks","Economy","National News"],"articleBody":"Sales of existing homes slid 1.5% in December, somewhat better than expected but the 11th straight month of decline, the National Association of Realtors said on Friday.The number was better than estimates of a 3.4% drop and brings the annual rate of home sales just a hair above 4 million. Sales are now down 34% from year-ago levels.“December was another difficult month for buyers, who continue to face limited inventory and high mortgage rates,” said NAR Chief Economist Lawrence Yun. “However, expect sales to pick up again soon since mortgage rates have markedly declined after peaking late last year.”Prices, meanwhile, were slightly higher with the median selling price of $366,900 coming in at 2.3% above a year ago.Housing has taken it on the chin since the Federal Reserve began raising interest rates in earnest last year to bring down inflation. The Fed meets Jan. 31 to Feb. 1 and is widely expected to hike rates again, most likely by a quarter percentage point. Recently, top Fed officials have sounded the message they are not finished with raising rates.Mortgage rates have doubled over the past year, although there has been some relief of late. While that directly affects the ability of would-be homeowners to afford a new home, it has also kept sellers on the sidelines as they may have mortgages with rates at or below 3% and so be less eager to move.“Most homeowners still have a significant equity cushion that should give them a good number of options if they are contemplating a sale,” Danielle Hale, Realtor.com chief economist, said ahead of the report’s release.“However, evaporating demand has ended the strong sellers market of the past several years, and still-falling home sales tell us that many buyers are still not able to afford a purchase or not yet convinced that the market is tilted sufficiently in their favor to move forward,” Hale added. “The housing market is entering ‘nobody’s market’ territory as buyers and sellers remain largely in a stalemate.”In the new home market, builders have been offering incentives and paying down some mortgages to entice buyers. The National Association of Home Builders saw a slight increase in builder confidence in January, according to the release of its monthly survey on Wednesday.","@type":"NewsArticle","author":[{"image":"https://www.usnews.com/dims4/USNEWS/e6a8f2e/2147483647/thumbnail/300x300/quality/85/?url=https%3A%2F%2Fwww.usnews.com%2Fcmsmedia%2F6e%2F2b2a0aca6c20389d63a1ab915962ce%2F36425Smart_Tim.jpg","@type":"Person","jobTitle":"Contributing Editor","name":"Tim Smart","url":"https://www.usnews.com/topics/author/tim_smart"}],"description":"The performance was better than expected and prices inched up a little from a year ago.","dateModified":"2023-01-20T10:44-0500","mainEntityOfPage":{"@type":"WebPage","name":"Existing Homes Fall 1.5% in December, Marking 11th Month of Declines","@id":"https://www.usnews.com/news/economy/articles/2023-01-20/existing-homes-fall-1-5-in-december-marking-11th-month-of-declines","url":"https://www.usnews.com/news/economy/articles/2023-01-20/existing-homes-fall-1-5-in-december-marking-11th-month-of-declines"},"@context":"http://www.schema.org","datePublished":"2023-01-20T10:41-0500","dateCreated":"2023-01-20T10:41-0500","publisher":{"@type":"Organization","name":"U.S. News & World Report","logo":{"@type":"ImageObject","width":193,"url":"https://www.usnews.com/static/images/usn-logo-print.png","height":46}},"headline":"Existing Homes Fall 1.5% in December, Marking 11th Month of Declines","thumbnailUrl":"https://www.usnews.com/dims4/USNEWS/6385807/214748364 ...
#   </script>
#   <script crossorigin="anonymous" data-rh="true" defer="true" integrity="sha256-9/aliU8dGd2tb6OSsuzixeV4y/faTqgFtohetphbbj0=" src="https://code.jquery.com/jquery-3.5.1.min.js">
#   </script>
#   <script data-rh="true" defer="true" src="https://tags.tiqcdn.com/utag/usnews/main/prod/utag.js">
#   </script>
#   <script data-env="null" data-rh="true" id="request-info" type="application/json">
#    {"environment":null,"port":null,"environment_affix":"","subdomain":"www","request_url":"https://www.usnews.com/news/economy/articles/2023-01-20/existing-homes-fall-1-5-in-december-marking-11th-month-of-declines"}
#   </script>
#   <script data-partner-name="nativo" data-rh="true">
#    //This is a hack to trick Tealium into thinking Nativo is on the page so we can control when it loads.
#   </script>
#   <script data-rh="true" src="https://ak.sail-horizon.com/spm/spm.v1.min.js">
#   </script>
#   <style data-rh="true">
#    /* Stop smooth scrolling if reduced-motion is enabled */
#         @media (prefers-reduced-motion: reduce) {
#             html {
#                 scroll-behavior: auto !important;
#             }
#         }
#   </style>
#   <link data-rh="true" href="/static/images/favicon.ico" rel="shortcut icon"/>
#   <link data-rh="true" href="/static-atlas/assets/img/social-logo-world-report.png" rel="apple-touch-icon" type="image/png"/>
#   <link data-rh="true" data-test-id="relCanonical" href="https://www.usnews.com/news/economy/articles/2023-01-20/existing-homes-fall-1-5-in-december-marking-11th-month-of-declines" rel="canonical"/>
#   <link as="script" data-rh="true" href="https://cse.google.com/cse.js?cx=009692862532464842631:ioemuhgr76n" rel="prefetch"/>
#   <style data-styled="true" data-styled-version="5.3.3">
#    :root{--black-90:#1A1D26;--black-80:#2C303C;--black-70:#3F4451;--gray-50:#515767;--gray-30:#6F7480;--gray-20:#9297A1;--gray-15:#D3D7DC;--gray-10:#E4E7EB;--gray-05:#F4F7F9;--white-00:#ffffff;--red-90:#871A18;--red-80:#A4211F;--red-70:#B92523;--red-50:#CE2927;--red-30:#EB625F;--red-20:#F58987;--red-15:#FCBAB9;--red-10:#FDD5D4;--red-05:#FFF0EF;--orange-90:#C94D00;--orange-80:#DD7E00;--orange-70:#E89A00;--yellow-50:#F1B303;--yellow-30:#F7CE27;--yellow-20:#FBE25C;--yellow-15:#FEF2A0;--yellow-10:#FEF8C6;--yellow-05:#FFFDEB;--green-90:#024024;--green-80:#005E31;--green-70:#06844B;--green-50:#24BB80;--green-30:#38D38D;--green-20:#97EFB2;--green-15:#C4F9D6;--green-10:#DBFBE8;--green-05:#F0FFEF;--blue-90:#00206B;--blue-80:#033493;--blue-70:#064AB7;--blue-50:#1263D3;--blue-30:#358CE7;--blue-20:#6AB4F4;--blue-15:#B1DCFB;--blue-10:#D6EEFD;--blue-05:#EFF8FF;--violet-90:#240C33;--violet-80:#3D1455;--violet-70:#512386;--violet-50:#5A37AE;--violet-30:#624FCC;--violet-20:#7D79DF;--violet-15:#97A3F1;--violet-10:#C7D4FA;--violet-05:#E9EEFC;--muted:#515767;--font-primary:"Roboto",Helvetica Neue,Helvetica,sans-serif;--font-secondary:"Montserrat",Helvetica Neue,Helvetica,sans-serif;font-family:var(--font-primary);-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;text-rendering:optimizeLegibility;-webkit-text-size-adjust:none;text-size-adjust:none;color:var(--black-90);}/*!sc*/
# html{background-color:var(--white-00);}/*!sc*/
# a{-webkit-text-decoration:none;text-decoration:none;color:var(--blue-50);-webkit-transition:color 0.5s;transition:color 0.5s;}/*!sc*/
# a:hover,a:active{color:var(--blue-90);}/*!sc*/
# data-styled.g1[id="sc-global-fYTvay1"]{content:"sc-global-fYTvay1,"}/*!sc*/
# .bGXiGV{--color:var(--white-00);--bg-color:var(--red-50);--bg-color-hover:rgba(166,28,30,1);--bg-color-active:var(--bg-color-hover);--border-color:var(--red-90);--bs:rgb(51 51 51 / 50%) 0px 1px 3px;--bs-hover:rgb(255 255 255) 0px 0px 0px 1px,rgb(196 33 42) 0px 0px 0px 3px;--bs-active:rgb(51 51 51 / 20%) 1px 1px 0px;--horizontal-spacing:1rem;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-flex-wrap:nowrap;-ms-flex-wrap:nowrap;flex-wrap:nowrap;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;-webkit-appearance:none;-moz-appearance:none;appearance:none;color:var(--color);background:var(--bg-color);cursor:pointer;box-sizing:border-box;height:40px;margin:0;padding:0 var(--horizontal-spacing);font-family:var(--font-primary);font-size:0.875rem;font-weight:700;line-height:1.4;-webkit-text-decoration:none;text-decoration:none;outline:none;border:none;border-color:var(--border-color);border-radius:0.25rem;box-shadow:var(--bs);-webkit-transition-property:background,color,box-shadow,border;transition-property:background,color,box-shadow,border;-webkit-transition-duration:0.6s;transition-duration:0.6s;-webkit-transition-timing-function:cubic-bezier(.2,.8,.2,1);transition-timing-function:cubic-bezier(.2,.8,.2,1);}/*!sc*/
# .bGXiGV.full-width{width:100%;}/*!sc*/
# .bGXiGV.type-secondary{--color:var(--blue-50);--bg-color:var(--white-00);--bg-color-hover:var(--blue-05);--bg-color-active:var(--blue-10);--border-color:var(--blue-50);--bs:inset 0px 0px 0px 1px #115abf,rgb(51 51 51 / 30%) 0px 1px 3px;--bs-hover:inset 0px 0px 0px 1px #115abf,rgb(255 255 255) 0px 0px 0px 1px,#115abf 0px 0px 0px 3px;--bs-active:inset 0px 0px 0px 1px #115abf;}/*!sc*/
# .bGXiGV.type-tertiary{--bg-color:var(--blue-50);--bg-color-hover:var(--blue-90);--bg-color-active:var(--blue-90);--border-color:var(--blue-90);--bs-hover:rgb(255 255 255) 0px 0px 0px 1px,rgb(17 90 191) 0px 0px 0px 3px;}/*!sc*/
# .bGXiGV.type-overlay{--bg-color:rgba(51,51,51,.7);--bg-color-hover:rgba(34,34,34,.8);--bg-color-active:var(--black-70);--border-color:rgba(17,17,17,.6);--bs-hover:rgb(255 255 255) 0px 0px 0px 1px,rgb(51 51 51 / 70%) 0px 0px 0px 3px;}/*!sc*/
# .bGXiGV.type-outline{--color:var(--red-50);--bg-color:var(--white-00);--bg-color-hover:var(--red-05);--bg-color-active:var(--red-10);--border-color:var(--red-50);--bs:inset 0px 0px 0px 1px var(--red-50),rgb(51 51 51 / 30%) 0px 1px 3px;--bs-hover:inset 0px 0px 0px 1px var(--red-50),rgb(255 255 255) 0px 0px 0px 1px,var(--red-50) 0px 0px 0px 3px;--bs-active:inset 0px 0px 0px 1px var(--red-50);}/*!sc*/
# @media (hover:hover){.bGXiGV:hover:not(:disabled):not(:active){color:var(--color);background:var(--bg-color-hover);box-shadow:var(--bs-hover);}}/*!sc*/
# .bGXiGV:focus-visible{background:var(--bg-color-hover);box-shadow:var(--bs-hover);}/*!sc*/
# .bGXiGV:active{background:var(--bg-color-hover);box-shadow:var(--bs-active);}/*!sc*/
# .bGXiGV.size-large{font-size:1rem;line-height:1.5;height:50px;}/*!sc*/
# .bGXiGV.size-small{--horizontal-spacing:0.75rem;height:30px;}/*!sc*/
# .bGXiGV.size-xSmall{--horizontal-spacing:0.5rem;font-size:0.625rem;line-height:1.2;height:20px;}/*!sc*/
# .bGXiGV .button__Section-sc-1vhaw8r-0{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;padding:0;}/*!sc*/
# .bGXiGV .button__Section-sc-1vhaw8r-0 + .button__Section-sc-1vhaw8r-0{padding-left:var(--horizontal-spacing);margin-left:var(--horizontal-spacing);border-left:1px solid;border-color:inherit;}/*!sc*/
# .bGXiGV:disabled{background:rgba(170,170,170,.9);color:var(--gray-50);border-color:var(--gray-30);box-shadow:none;cursor:not-allowed;}/*!sc*/
# data-styled.g21[id="button__ButtonStyled-sc-1vhaw8r-1"]{content:"bGXiGV,"}/*!sc*/
# .bemVuC{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;min-height:250px;}/*!sc*/
# .bemVuC >:last-child{position:relative;}/*!sc*/
# data-styled.g28[id="ad-spacer__AdSpacer-sc-nwg9sv-0"]{content:"bemVuC,"}/*!sc*/
# .hCtXtP{--font-size:0.875rem;--line-height:1.4;--clear-button-size:30px;--clear-button-top:5px;--padding-top:0;--padding-horizontal:0.5rem;--border-color:var(--black-70);--label-top:10px;--label-top-focused:5px;--label-font-size-focused:0.625rem;position:relative;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;box-sizing:border-box;width:var(--width,'auto');min-width:0;max-width:100%;font-family:var(--font-primary);color:var(--black-90);}/*!sc*/
# .hCtXtP input{height:40px;}/*!sc*/
# .hCtXtP:not(.is-clearable) input:hover:not(:disabled),.hCtXtP input:focus,.hCtXtP.touched input:invalid:not(:focus),.hCtXtP.has-error input{box-shadow:var(--white-00) 0px 0px 0px 1px,var(--border-color) 0px 0px 0px 3px;}/*!sc*/
# .hCtXtP.has-label{--padding-top:0.5rem;}/*!sc*/
# .hCtXtP.size-small{--font-size:0.75rem;--line-height:1.33;--clear-button-size:28px;--clear-button-top:1px;--label-top:8px;--label-top-focused:4px;--label-font-size-focused:0.5rem;}/*!sc*/
# .hCtXtP.size-small.has-label{--padding-top:10px;}/*!sc*/
# .hCtXtP.size-small input{height:30px;}/*!sc*/
# .hCtXtP.size-large{--font-size:1rem;--line-height:1.5;--clear-button-size:32px;--clear-button-top:9px;--padding-horizontal:0.75rem;--label-top:13px;--label-top-focused:10px;}/*!sc*/
# .hCtXtP.size-large.has-label{--padding-top:0.75rem;}/*!sc*/
# .hCtXtP.size-large input{height:50px;}/*!sc*/
# .hCtXtP.is-clearable:not(.has-error){--border-color:var(--blue-50);}/*!sc*/
# .hCtXtP.is-clearable input{padding-right:calc(var(--padding-horizontal) + var(--clear-button-size));box-shadow:inset 0 0 0 2px var(--border-color);}/*!sc*/
# .hCtXtP input:disabled{--border-color:var(--gray-30);}/*!sc*/
# .hCtXtP.has-error input,.hCtXtP.touched input:invalid:not(:focus){--border-color:var(--red-50);}/*!sc*/
# data-styled.g43[id="text-input__Container-sc-md09ji-0"]{content:"hCtXtP,"}/*!sc*/
# .hIxYVP{position:relative;box-sizing:border-box;width:100%;outline:none;}/*!sc*/
# data-styled.g44[id="text-input__LabelStyled-sc-md09ji-1"]{content:"hIxYVP,"}/*!sc*/
# .jpzloU{-webkit-appearance:none;-moz-appearance:none;appearance:none;box-sizing:border-box;width:100%;padding:var(--padding-top) var(--padding-horizontal) 0 var(--padding-horizontal);margin:0;border:1px solid var(--border-color);border-radius:0.25rem;outline:none;background:var(--white-00);font-family:var(--font-primary);font-size:var(--font-size);line-height:var(--line-height);-webkit-transition-property:box-shadow,border,background;transition-property:box-shadow,border,background;-webkit-transition-duration:600ms;transition-duration:600ms;-webkit-transition-timing-function:cubic-bezier(.2,.8,.2,1);transition-timing-function:cubic-bezier(.2,.8,.2,1);}/*!sc*/
# .jpzloU:disabled{color:var(--gray-30);background:rgba(211,215,220,.9);cursor:not-allowed;}/*!sc*/
# .jpzloU::-webkit-datetime-edit,.jpzloU::-webkit-datetime-edit-text,.jpzloU::-webkit-datetime-edit-month-field,.jpzloU::-webkit-datetime-edit-day-field,.jpzloU::-webkit-datetime-edit-year-field{padding:0;}/*!sc*/
# data-styled.g45[id="text-input__InputStyled-sc-md09ji-2"]{content:"jpzloU,"}/*!sc*/
# .eJAyFO{position:fixed;left:1rem;bottom:68px;max-width:calc(100% - 2rem);box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;z-index:10000;}/*!sc*/
# @media (min-width:640px){.eJAyFO{max-width:415px;}}/*!sc*/
# @media (min-width:1024px){.eJAyFO{bottom:125px;}}/*!sc*/
# data-styled.g66[id="overlay__Container-sc-1mwbfqy-0"]{content:"eJAyFO,"}/*!sc*/
# html{background-color:var(--black-90);-webkit-scroll-behavior:smooth;-moz-scroll-behavior:smooth;-ms-scroll-behavior:smooth;scroll-behavior:smooth;-webkit-scroll-padding-top:4rem;-moz-scroll-padding-top:4rem;-ms-scroll-padding-top:4rem;scroll-padding-top:4rem;}/*!sc*/
# @media (prefers-reduced-motion:reduce){html{-webkit-scroll-behavior:auto !important;-moz-scroll-behavior:auto !important;-ms-scroll-behavior:auto !important;scroll-behavior:auto !important;}}/*!sc*/
# html[data-disable-js=true] [data-test-remove=true]{display:none;}/*!sc*/
# body{background-color:var(--white-00);min-height:100vh;margin:0;overflow-x:hidden;}/*!sc*/
# lazy-background{box-sizing:border-box;}/*!sc*/
# data-styled.g67[id="sc-global-gczUDA1"]{content:"sc-global-gczUDA1,"}/*!sc*/
# div{box-sizing:border-box;}/*!sc*/
# .hide{display:none!important;}/*!sc*/
# @media (max-width:639px){.sm-hide{display:none!important;}}/*!sc*/
# @media (min-width:640px) and (max-width:1023px){.md-hide{display:none!important;}}/*!sc*/
# @media (min-width:1024px){.lg-hide{display:none!important;}}/*!sc*/
# @media (min-width:640px) and (max-width:767px){.ms-hide{display:none!important;}}/*!sc*/
# @media (min-width:768px) and (max-width:1023px){.ml-hide{display:none!important;}}/*!sc*/
# .visually-hidden{position:absolute;height:1px;width:1px;padding:0;margin:-1px;border:0;-webkit-clip:rect(0,0,0,0);clip:rect(0,0,0,0);overflow:hidden;}/*!sc*/
# .flex{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .flex-column{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .white{color:#fff;}/*!sc*/
# .gray{color:#ccc;}/*!sc*/
# .lightgray{color:#f7f7f7;}/*!sc*/
# .darkgray{color:#666;}/*!sc*/
# .bg-gray{background-color:#ccc;}/*!sc*/
# .bg-lightgray{background-color:#f7f7f7;}/*!sc*/
# .bg-darkgray{background-color:#666;}/*!sc*/
# .black90{color:#111;}/*!sc*/
# .black80{color:#222;}/*!sc*/
# .black70{color:#333;}/*!sc*/
# .t0,.t1,.t2,.t3,.t4,.t5,.t6,.t7,.t-font-fam{font-family:Roboto,Helvetica Neue,Helvetica,sans-serif;margin:0;}/*!sc*/
# .t0{font-size:.625rem;line-height:1.2;}/*!sc*/
# .t1{font-size:.75rem;line-height:1.3;}/*!sc*/
# .t2{font-size:.875rem;line-height:1.4;}/*!sc*/
# .t3{font-size:1rem;}/*!sc*/
# .t3,.t4{line-height:1.5;}/*!sc*/
# .t4{font-size:1.125rem;}/*!sc*/
# .t5{font-size:1.25rem;line-height:1.4;}/*!sc*/
# .t6{font-size:1.5rem;line-height:1.33;}/*!sc*/
# .t7{font-size:2rem;line-height:1.25;}/*!sc*/
# @media (min-width:640px) and (max-width:1023px){.md-t0{font-size:.625rem;line-height:1.2;}.md-t1{font-size:.75rem;line-height:1.3;}.md-t2{font-size:.875rem;line-height:1.4;}.md-t3{font-size:1rem;}.md-t3,.md-t4{line-height:1.5;}.md-t4{font-size:1.125rem;}.md-t5{font-size:1.25rem;line-height:1.4;}.md-t6{font-size:1.5rem;line-height:1.33;}.md-t7{font-size:2rem;line-height:1.25;}}/*!sc*/
# @media (min-width:768px) and (max-width:1023px){.ml-t0{font-size:.625rem;line-height:1.2;}.ml-t1{font-size:.75rem;line-height:1.3;}.ml-t2{font-size:.875rem;line-height:1.4;}.ml-t3{font-size:1rem;}.ml-t3,.ml-t4{line-height:1.5;}.ml-t4{font-size:1.125rem;}.ml-t5{font-size:1.25rem;line-height:1.4;}.ml-t6{font-size:1.5rem;line-height:1.33;}.ml-t7{font-size:2rem;line-height:1.25;}}/*!sc*/
# @media (min-width:1024px){.lg-t0{font-size:.625rem;line-height:1.2;}.lg-t1{font-size:.75rem;line-height:1.3;}.lg-t2{font-size:.875rem;line-height:1.4;}.lg-t3{font-size:1rem;}.lg-t3,.lg-t4{line-height:1.5;}.lg-t4{font-size:1.125rem;}.lg-t5{font-size:1.25rem;line-height:1.4;}.lg-t6{font-size:1.5rem;line-height:1.33;}.lg-t7{font-size:2rem;line-height:1.25;}}/*!sc*/
# .h0,.h1,.h2,.h3,.h4,.h5,.h6,.h7,.h8,.h-font-fam{font-family:Montserrat,Helvetica Neue,Helvetica,sans-serif;margin:0;padding:0;}/*!sc*/
# .h0{font-size:.75rem;line-height:1.33;}/*!sc*/
# .h1{font-size:.875rem;line-height:1.42;}/*!sc*/
# .h2{font-size:1rem;line-height:1.25;}/*!sc*/
# .h3{font-size:1.125rem;line-height:1.33;}/*!sc*/
# .h4{font-size:1.25rem;line-height:1.2;}/*!sc*/
# .h5{font-size:1.5rem;line-height:1.33;}/*!sc*/
# .h6{font-size:2rem;line-height:1.25;}/*!sc*/
# .h7{font-size:2.625rem;line-height:1.14;}/*!sc*/
# .h8{font-size:3.125rem;line-height:1.12;}/*!sc*/
# @media (min-width:640px) and (max-width:1023px){.md-h0{font-size:.75rem;line-height:1.33;}.md-h1{font-size:.875rem;line-height:1.42;}.md-h2{font-size:1rem;line-height:1.25;}.md-h3{font-size:1.125rem;line-height:1.33;}.md-h4{font-size:1.25rem;line-height:1.2;}.md-h5{font-size:1.5rem;line-height:1.33;}.md-h6{font-size:2rem;line-height:1.25;}.md-h7{font-size:2.625rem;line-height:1.14;}.md-h8{font-size:3.125rem;line-height:1.12;}}/*!sc*/
# @media (min-width:768px) and (max-width:1023px){.ml-h0{font-size:.75rem;line-height:1.33;}.ml-h1{font-size:.875rem;line-height:1.42;}.ml-h2{font-size:1rem;line-height:1.25;}.ml-h3{font-size:1.125rem;line-height:1.33;}.ml-h4{font-size:1.25rem;line-height:1.2;}.ml-h5{font-size:1.5rem;line-height:1.33;}.ml-h6{font-size:2rem;line-height:1.25;}.ml-h7{font-size:2.625rem;line-height:1.14;}.ml-h8{font-size:3.125rem;line-height:1.12;}}/*!sc*/
# @media (min-width:1024px){.lg-h0{font-size:.75rem;line-height:1.33;}.lg-h1{font-size:.875rem;line-height:1.42;}.lg-h2{font-size:1rem;line-height:1.25;}.lg-h3{font-size:1.125rem;line-height:1.33;}.lg-h4{font-size:1.25rem;line-height:1.2;}.lg-h5{font-size:1.5rem;line-height:1.33;}.lg-h6{font-size:2rem;line-height:1.25;}.lg-h8{font-size:3.125rem;line-height:1.12;}}/*!sc*/
# .m0{margin:0 !important;}/*!sc*/
# .mt0{margin-top:0 !important;}/*!sc*/
# .mr0{margin-right:0 !important;}/*!sc*/
# .mb0{margin-bottom:0 !important;}/*!sc*/
# .ml0,.mx0{margin-left:0 !important;}/*!sc*/
# .mx0{margin-right:0 !important;}/*!sc*/
# .my0{margin-top:0 !important;margin-bottom:0 !important;}/*!sc*/
# .m1{margin:.125rem !important;}/*!sc*/
# .mt1{margin-top:.125rem !important;}/*!sc*/
# .mr1{margin-right:.125rem !important;}/*!sc*/
# .mb1{margin-bottom:.125rem !important;}/*!sc*/
# .ml1,.mx1{margin-left:.125rem !important;}/*!sc*/
# .mx1{margin-right:.125rem !important;}/*!sc*/
# .my1{margin-top:.125rem !important;margin-bottom:.125rem !important;}/*!sc*/
# .m2{margin:.25rem !important;}/*!sc*/
# .mt2{margin-top:.25rem !important;}/*!sc*/
# .mr2{margin-right:.25rem !important;}/*!sc*/
# .mb2{margin-bottom:.25rem !important;}/*!sc*/
# .ml2,.mx2{margin-left:.25rem !important;}/*!sc*/
# .mx2{margin-right:.25rem !important;}/*!sc*/
# .my2{margin-top:.25rem !important;margin-bottom:.25rem !important;}/*!sc*/
# .m3{margin:.5rem !important;}/*!sc*/
# .mt3{margin-top:.5rem !important;}/*!sc*/
# .mr3{margin-right:.5rem !important;}/*!sc*/
# .mb3{margin-bottom:.5rem !important;}/*!sc*/
# .ml3,.mx3{margin-left:.5rem !important;}/*!sc*/
# .mx3{margin-right:.5rem !important;}/*!sc*/
# .my3{margin-top:.5rem !important;margin-bottom:.5rem !important;}/*!sc*/
# .m4{margin:1rem !important;}/*!sc*/
# .mt4{margin-top:1rem !important;}/*!sc*/
# .mr4{margin-right:1rem !important;}/*!sc*/
# .mb4{margin-bottom:1rem !important;}/*!sc*/
# .ml4,.mx4{margin-left:1rem !important;}/*!sc*/
# .mx4{margin-right:1rem !important;}/*!sc*/
# .my4{margin-top:1rem !important;margin-bottom:1rem !important;}/*!sc*/
# .m5{margin:2rem !important;}/*!sc*/
# .mt5{margin-top:2rem !important;}/*!sc*/
# .mr5{margin-right:2rem !important;}/*!sc*/
# .mb5{margin-bottom:2rem !important;}/*!sc*/
# .ml5,.mx5{margin-left:2rem !important;}/*!sc*/
# .mx5{margin-right:2rem !important;}/*!sc*/
# .my5{margin-top:2rem !important;margin-bottom:2rem !important;}/*!sc*/
# .m6{margin:4rem !important;}/*!sc*/
# .mt6{margin-top:4rem !important;}/*!sc*/
# .mr6{margin-right:4rem !important;}/*!sc*/
# .mb6{margin-bottom:4rem !important;}/*!sc*/
# .ml6,.mx6{margin-left:4rem !important;}/*!sc*/
# .mx6{margin-right:4rem !important;}/*!sc*/
# .my6{margin-top:4rem !important;margin-bottom:4rem !important;}/*!sc*/
# .m-auto{margin:auto!important;}/*!sc*/
# .mt-auto{margin-top:auto!important;}/*!sc*/
# .mr-auto{margin-right:auto!important;}/*!sc*/
# .mb-auto{margin-bottom:auto!important;}/*!sc*/
# .ml-auto,.mx-auto{margin-left:auto!important;}/*!sc*/
# .mx-auto{margin-right:auto!important;}/*!sc*/
# .my-auto{margin-top:auto!important;margin-bottom:auto!important;}/*!sc*/
# @media (min-width:640px) and (max-width:1023px){.md-m0{margin:0 !important;}.md-mt0{margin-top:0 !important;}.md-mr0{margin-right:0 !important;}.md-mb0{margin-bottom:0 !important;}.md-ml0,.md-mx0{margin-left:0 !important;}.md-mx0{margin-right:0 !important;}.md-my0{margin-top:0 !important;margin-bottom:0 !important;}.md-m1{margin:.125rem !important;}.md-mt1{margin-top:.125rem !important;}.md-mr1{margin-right:.125rem !important;}.md-mb1{margin-bottom:.125rem !important;}.md-ml1,.md-mx1{margin-left:.125rem !important;}.md-mx1{margin-right:.125rem !important;}.md-my1{margin-top:.125rem !important;margin-bottom:.125rem !important;}.md-m2{margin:.25rem !important;}.md-mt2{margin-top:.25rem !important;}.md-mr2{margin-right:.25rem !important;}.md-mb2{margin-bottom:.25rem !important;}.md-ml2,.md-mx2{margin-left:.25rem !important;}.md-mx2{margin-right:.25rem !important;}.md-my2{margin-top:.25rem !important;margin-bottom:.25rem !important;}.md-m3{margin:.5rem !important;}.md-mt3{margin-top:.5rem !important;}.md-mr3{margin-right:.5rem !important;}.md-mb3{margin-bottom:.5rem !important;}.md-ml3,.md-mx3{margin-left:.5rem !important;}.md-mx3{margin-right:.5rem !important;}.md-my3{margin-top:.5rem !important;margin-bottom:.5rem !important;}.md-m4{margin:1rem !important;}.md-mt4{margin-top:1rem !important;}.md-mr4{margin-right:1rem !important;}.md-mb4{margin-bottom:1rem !important;}.md-ml4,.md-mx4{margin-left:1rem !important;}.md-mx4{margin-right:1rem !important;}.md-my4{margin-top:1rem !important;margin-bottom:1rem !important;}.md-m5{margin:2rem !important;}.md-mt5{margin-top:2rem !important;}.md-mr5{margin-right:2rem !important;}.md-mb5{margin-bottom:2rem !important;}.md-ml5,.md-mx5{margin-left:2rem !important;}.md-mx5{margin-right:2rem !important;}.md-my5{margin-top:2rem !important;margin-bottom:2rem !important;}.md-m6{margin:4rem !important;}.md-mt6{margin-top:4rem !important;}.md-mr6{margin-right:4rem !important;}.md-mb6{margin-bottom:4rem !important;}.md-ml6,.md-mx6{margin-left:4rem !important;}.md-mx6{margin-right:4rem !important;}.md-my6{margin-top:4rem !important;margin-bottom:4rem !important;}.md-m-auto{margin:auto!important;}.md-mt-auto{margin-top:auto!important;}.md-mr-auto{margin-right:auto!important;}.md-mb-auto{margin-bottom:auto!important;}.md-ml-auto,.md-mx-auto{margin-left:auto!important;}.md-mx-auto{margin-right:auto!important;}.md-my-auto{margin-top:auto!important;margin-bottom:auto!important;}}/*!sc*/
# @media (min-width:768px) and (max-width:1023px){.ml-m0{margin:0 !important;}.ml-mt0{margin-top:0 !important;}.ml-mr0{margin-right:0 !important;}.ml-mb0{margin-bottom:0 !important;}.ml-ml0,.ml-mx0{margin-left:0 !important;}.ml-mx0{margin-right:0 !important;}.ml-my0{margin-top:0 !important;margin-bottom:0 !important;}.ml-m1{margin:.125rem !important;}.ml-mt1{margin-top:.125rem !important;}.ml-mr1{margin-right:.125rem !important;}.ml-mb1{margin-bottom:.125rem !important;}.ml-ml1,.ml-mx1{margin-left:.125rem !important;}.ml-mx1{margin-right:.125rem !important;}.ml-my1{margin-top:.125rem !important;margin-bottom:.125rem !important;}.ml-m2{margin:.25rem !important;}.ml-mt2{margin-top:.25rem !important;}.ml-mr2{margin-right:.25rem !important;}.ml-mb2{margin-bottom:.25rem !important;}.ml-ml2,.ml-mx2{margin-left:.25rem !important;}.ml-mx2{margin-right:.25rem !important;}.ml-my2{margin-top:.25rem !important;margin-bottom:.25rem !important;}.ml-m3{margin:.5rem !important;}.ml-mt3{margin-top:.5rem !important;}.ml-mr3{margin-right:.5rem !important;}.ml-mb3{margin-bottom:.5rem !important;}.ml-ml3,.ml-mx3{margin-left:.5rem !important;}.ml-mx3{margin-right:.5rem !important;}.ml-my3{margin-top:.5rem !important;margin-bottom:.5rem !important;}.ml-m4{margin:1rem !important;}.ml-mt4{margin-top:1rem !important;}.ml-mr4{margin-right:1rem !important;}.ml-mb4{margin-bottom:1rem !important;}.ml-ml4,.ml-mx4{margin-left:1rem !important;}.ml-mx4{margin-right:1rem !important;}.ml-my4{margin-top:1rem !important;margin-bottom:1rem !important;}.ml-m5{margin:2rem !important;}.ml-mt5{margin-top:2rem !important;}.ml-mr5{margin-right:2rem !important;}.ml-mb5{margin-bottom:2rem !important;}.ml-ml5,.ml-mx5{margin-left:2rem !important;}.ml-mx5{margin-right:2rem !important;}.ml-my5{margin-top:2rem !important;margin-bottom:2rem !important;}.ml-m6{margin:4rem !important;}.ml-mt6{margin-top:4rem !important;}.ml-mr6{margin-right:4rem !important;}.ml-mb6{margin-bottom:4rem !important;}.ml-ml6,.ml-mx6{margin-left:4rem !important;}.ml-mx6{margin-right:4rem !important;}.ml-my6{margin-top:4rem !important;margin-bottom:4rem !important;}.ml-m-auto{margin:auto!important;}.ml-mt-auto{margin-top:auto!important;}.ml-mr-auto{margin-right:auto!important;}.ml-mb-auto{margin-bottom:auto!important;}.ml-ml-auto,.ml-mx-auto{margin-left:auto!important;}.ml-mx-auto{margin-right:auto!important;}.ml-my-auto{margin-top:auto!important;margin-bottom:auto!important;}}/*!sc*/
# @media (min-width:1024px){.lg-m0{margin:0 !important;}.lg-mt0{margin-top:0 !important;}.lg-mr0{margin-right:0 !important;}.lg-mb0{margin-bottom:0 !important;}.lg-ml0,.lg-mx0{margin-left:0 !important;}.lg-mx0{margin-right:0 !important;}.lg-my0{margin-top:0 !important;margin-bottom:0 !important;}.lg-m1{margin:.125rem !important;}.lg-mt1{margin-top:.125rem !important;}.lg-mr1{margin-right:.125rem !important;}.lg-mb1{margin-bottom:.125rem !important;}.lg-ml1,.lg-mx1{margin-left:.125rem !important;}.lg-mx1{margin-right:.125rem !important;}.lg-my1{margin-top:.125rem !important;margin-bottom:.125rem !important;}.lg-m2{margin:.25rem !important;}.lg-mt2{margin-top:.25rem !important;}.lg-mr2{margin-right:.25rem !important;}.lg-mb2{margin-bottom:.25rem !important;}.lg-ml2,.lg-mx2{margin-left:.25rem !important;}.lg-mx2{margin-right:.25rem !important;}.lg-my2{margin-top:.25rem !important;margin-bottom:.25rem !important;}.lg-m3{margin:.5rem !important;}.lg-mt3{margin-top:.5rem !important;}.lg-mr3{margin-right:.5rem !important;}.lg-mb3{margin-bottom:.5rem !important;}.lg-ml3,.lg-mx3{margin-left:.5rem !important;}.lg-mx3{margin-right:.5rem !important;}.lg-my3{margin-top:.5rem !important;margin-bottom:.5rem !important;}.lg-m4{margin:1rem !important;}.lg-mt4{margin-top:1rem !important;}.lg-mr4{margin-right:1rem !important;}.lg-mb4{margin-bottom:1rem !important;}.lg-ml4,.lg-mx4{margin-left:1rem !important;}.lg-mx4{margin-right:1rem !important;}.lg-my4{margin-top:1rem !important;margin-bottom:1rem !important;}.lg-m5{margin:2rem !important;}.lg-mt5{margin-top:2rem !important;}.lg-mr5{margin-right:2rem !important;}.lg-mb5{margin-bottom:2rem !important;}.lg-ml5,.lg-mx5{margin-left:2rem !important;}.lg-mx5{margin-right:2rem !important;}.lg-my5{margin-top:2rem !important;margin-bottom:2rem !important;}.lg-m6{margin:4rem !important;}.lg-mt6{margin-top:4rem !important;}.lg-mr6{margin-right:4rem !important;}.lg-mb6{margin-bottom:4rem !important;}.lg-ml6,.lg-mx6{margin-left:4rem !important;}.lg-mx6{margin-right:4rem !important;}.lg-my6{margin-top:4rem !important;margin-bottom:4rem !important;}.lg-m-auto{margin:auto!important;}.lg-mt-auto{margin-top:auto!important;}.lg-mr-auto{margin-right:auto!important;}.lg-mb-auto{margin-bottom:auto!important;}.lg-ml-auto,.lg-mx-auto{margin-left:auto!important;}.lg-mx-auto{margin-right:auto!important;}.lg-my-auto{margin-top:auto!important;margin-bottom:auto!important;}}/*!sc*/
# .p0{padding:0 !important;}/*!sc*/
# .pt0{padding-top:0 !important;}/*!sc*/
# .pr0{padding-right:0 !important;}/*!sc*/
# .pb0{padding-bottom:0 !important;}/*!sc*/
# .pl0,.px0{padding-left:0 !important;}/*!sc*/
# .px0{padding-right:0 !important;}/*!sc*/
# .py0{padding-top:0 !important;padding-bottom:0 !important;}/*!sc*/
# .p1{padding:.5rem !important;}/*!sc*/
# .pt1{padding-top:.5rem !important;}/*!sc*/
# .pr1{padding-right:.5rem !important;}/*!sc*/
# .pb1{padding-bottom:.5rem !important;}/*!sc*/
# .pl1,.px1{padding-left:.5rem !important;}/*!sc*/
# .px1{padding-right:.5rem !important;}/*!sc*/
# .py1{padding-top:.5rem !important;padding-bottom:.5rem !important;}/*!sc*/
# .p2{padding:1rem !important;}/*!sc*/
# .pt2{padding-top:1rem !important;}/*!sc*/
# .pr2{padding-right:1rem !important;}/*!sc*/
# .pb2{padding-bottom:1rem !important;}/*!sc*/
# .pl2,.px2{padding-left:1rem !important;}/*!sc*/
# .px2{padding-right:1rem !important;}/*!sc*/
# .py2{padding-top:1rem !important;padding-bottom:1rem !important;}/*!sc*/
# .p3{padding:2rem !important;}/*!sc*/
# .pt3{padding-top:2rem !important;}/*!sc*/
# .pr3{padding-right:2rem !important;}/*!sc*/
# .pb3{padding-bottom:2rem !important;}/*!sc*/
# .pl3,.px3{padding-left:2rem !important;}/*!sc*/
# .px3{padding-right:2rem !important;}/*!sc*/
# .py3{padding-top:2rem !important;padding-bottom:2rem !important;}/*!sc*/
# .p4{padding:3rem !important;}/*!sc*/
# .pt4{padding-top:3rem !important;}/*!sc*/
# .pr4{padding-right:3rem !important;}/*!sc*/
# .pb4{padding-bottom:3rem !important;}/*!sc*/
# .pl4,.px4{padding-left:3rem !important;}/*!sc*/
# .px4{padding-right:3rem !important;}/*!sc*/
# .py4{padding-top:3rem !important;padding-bottom:3rem !important;}/*!sc*/
# .p5{padding:4rem !important;}/*!sc*/
# .pt5{padding-top:4rem !important;}/*!sc*/
# .pr5{padding-right:4rem !important;}/*!sc*/
# .pb5{padding-bottom:4rem !important;}/*!sc*/
# .pl5,.px5{padding-left:4rem !important;}/*!sc*/
# .px5{padding-right:4rem !important;}/*!sc*/
# .py5{padding-top:4rem !important;padding-bottom:4rem !important;}/*!sc*/
# @media (min-width:640px) and (max-width:1023px){.md-p0{padding:0 !important;}.md-pt0{padding-top:0 !important;}.md-pr0{padding-right:0 !important;}.md-pb0{padding-bottom:0 !important;}.md-pl0,.md-px0{padding-left:0 !important;}.md-px0{padding-right:0 !important;}.md-py0{padding-top:0 !important;padding-bottom:0 !important;}.md-p1{padding:.5rem !important;}.md-pt1{padding-top:.5rem !important;}.md-pr1{padding-right:.5rem !important;}.md-pb1{padding-bottom:.5rem !important;}.md-pl1,.md-px1{padding-left:.5rem !important;}.md-px1{padding-right:.5rem !important;}.md-py1{padding-top:.5rem !important;padding-bottom:.5rem !important;}.md-p2{padding:1rem !important;}.md-pt2{padding-top:1rem !important;}.md-pr2{padding-right:1rem !important;}.md-pb2{padding-bottom:1rem !important;}.md-pl2,.md-px2{padding-left:1rem !important;}.md-px2{padding-right:1rem !important;}.md-py2{padding-top:1rem !important;padding-bottom:1rem !important;}.md-p3{padding:2rem !important;}.md-pt3{padding-top:2rem !important;}.md-pr3{padding-right:2rem !important;}.md-pb3{padding-bottom:2rem !important;}.md-pl3,.md-px3{padding-left:2rem !important;}.md-px3{padding-right:2rem !important;}.md-py3{padding-top:2rem !important;padding-bottom:2rem !important;}.md-p4{padding:3rem !important;}.md-pt4{padding-top:3rem !important;}.md-pr4{padding-right:3rem !important;}.md-pb4{padding-bottom:3rem !important;}.md-pl4,.md-px4{padding-left:3rem !important;}.md-px4{padding-right:3rem !important;}.md-py4{padding-top:3rem !important;padding-bottom:3rem !important;}.md-p5{padding:4rem !important;}.md-pt5{padding-top:4rem !important;}.md-pr5{padding-right:4rem !important;}.md-pb5{padding-bottom:4rem !important;}.md-pl5,.md-px5{padding-left:4rem !important;}.md-px5{padding-right:4rem !important;}.md-py5{padding-top:4rem !important;padding-bottom:4rem !important;}}/*!sc*/
# @media (min-width:768px) and (max-width:1023px){.ml-p0{padding:0 !important;}.ml-pt0{padding-top:0 !important;}.ml-pr0{padding-right:0 !important;}.ml-pb0{padding-bottom:0 !important;}.ml-pl0,.ml-px0{padding-left:0 !important;}.ml-px0{padding-right:0 !important;}.ml-py0{padding-top:0 !important;padding-bottom:0 !important;}.ml-p1{padding:.5rem !important;}.ml-pt1{padding-top:.5rem !important;}.ml-pr1{padding-right:.5rem !important;}.ml-pb1{padding-bottom:.5rem !important;}.ml-pl1,.ml-px1{padding-left:.5rem !important;}.ml-px1{padding-right:.5rem !important;}.ml-py1{padding-top:.5rem !important;padding-bottom:.5rem !important;}.ml-p2{padding:1rem !important;}.ml-pt2{padding-top:1rem !important;}.ml-pr2{padding-right:1rem !important;}.ml-pb2{padding-bottom:1rem !important;}.ml-pl2,.ml-px2{padding-left:1rem !important;}.ml-px2{padding-right:1rem !important;}.ml-py2{padding-top:1rem !important;padding-bottom:1rem !important;}.ml-p3{padding:2rem !important;}.ml-pt3{padding-top:2rem !important;}.ml-pr3{padding-right:2rem !important;}.ml-pb3{padding-bottom:2rem !important;}.ml-pl3,.ml-px3{padding-left:2rem !important;}.ml-px3{padding-right:2rem !important;}.ml-py3{padding-top:2rem !important;padding-bottom:2rem !important;}.ml-p4{padding:3rem !important;}.ml-pt4{padding-top:3rem !important;}.ml-pr4{padding-right:3rem !important;}.ml-pb4{padding-bottom:3rem !important;}.ml-pl4,.ml-px4{padding-left:3rem !important;}.ml-px4{padding-right:3rem !important;}.ml-py4{padding-top:3rem !important;padding-bottom:3rem !important;}.ml-p5{padding:4rem !important;}.ml-pt5{padding-top:4rem !important;}.ml-pr5{padding-right:4rem !important;}.ml-pb5{padding-bottom:4rem !important;}.ml-pl5,.ml-px5{padding-left:4rem !important;}.ml-px5{padding-right:4rem !important;}.ml-py5{padding-top:4rem !important;padding-bottom:4rem !important;}}/*!sc*/
# @media (min-width:1024px){.lg-p0{padding:0 !important;}.lg-pt0{padding-top:0 !important;}.lg-pr0{padding-right:0 !important;}.lg-pb0{padding-bottom:0 !important;}.lg-pl0,.lg-px0{padding-left:0 !important;}.lg-px0{padding-right:0 !important;}.lg-py0{padding-top:0 !important;padding-bottom:0 !important;}.lg-p1{padding:.5rem !important;}.lg-pt1{padding-top:.5rem !important;}.lg-pr1{padding-right:.5rem !important;}.lg-pb1{padding-bottom:.5rem !important;}.lg-pl1,.lg-px1{padding-left:.5rem !important;}.lg-px1{padding-right:.5rem !important;}.lg-py1{padding-top:.5rem !important;padding-bottom:.5rem !important;}.lg-p2{padding:1rem !important;}.lg-pt2{padding-top:1rem !important;}.lg-pr2{padding-right:1rem !important;}.lg-pb2{padding-bottom:1rem !important;}.lg-pl2,.lg-px2{padding-left:1rem !important;}.lg-px2{padding-right:1rem !important;}.lg-py2{padding-top:1rem !important;padding-bottom:1rem !important;}.lg-p3{padding:2rem !important;}.lg-pt3{padding-top:2rem !important;}.lg-pr3{padding-right:2rem !important;}.lg-pb3{padding-bottom:2rem !important;}.lg-pl3,.lg-px3{padding-left:2rem !important;}.lg-px3{padding-right:2rem !important;}.lg-py3{padding-top:2rem !important;padding-bottom:2rem !important;}.lg-p4{padding:3rem !important;}.lg-pt4{padding-top:3rem !important;}.lg-pr4{padding-right:3rem !important;}.lg-pb4{padding-bottom:3rem !important;}.lg-pl4,.lg-px4{padding-left:3rem !important;}.lg-px4{padding-right:3rem !important;}.lg-py4{padding-top:3rem !important;padding-bottom:3rem !important;}.lg-p5{padding:4rem !important;}.lg-pt5{padding-top:4rem !important;}.lg-pr5{padding-right:4rem !important;}.lg-pb5{padding-bottom:4rem !important;}.lg-pl5,.lg-px5{padding-left:4rem !important;}.lg-px5{padding-right:4rem !important;}.lg-py5{padding-top:4rem !important;padding-bottom:4rem !important;}}/*!sc*/
# .border{border:1px solid #ccc;}/*!sc*/
# .border-none{border:0!important;}/*!sc*/
# .border-top{border-top:1px solid #ccc;}/*!sc*/
# .border-right{border-right:1px solid #ccc;}/*!sc*/
# .border-bottom{border-bottom:1px solid #ccc;}/*!sc*/
# .border-left{border-left:1px solid #ccc;}/*!sc*/
# ...
#           <p class="Paragraph-sc-1iyax29-0 Columns__ItemHeading-sc-10ug1wf-3 cvdqge iSItOL">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://www.usnews.com/news/the-report">
#             The Report
#            </a>
#           </p>
#           <div class="Columns__Items-sc-10ug1wf-2 gtptbF sm-hide md-hide">
#           </div>
#          </div>
#          <div class="Columns__Item-sc-10ug1wf-1 eBAVoM">
#           <p class="Paragraph-sc-1iyax29-0 Columns__ItemHeading-sc-10ug1wf-3 cvdqge iSItOL">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://www.usnews.com/photos">
#             Photos
#            </a>
#           </p>
#           <div class="Columns__Items-sc-10ug1wf-2 gtptbF sm-hide md-hide">
#           </div>
#          </div>
#          <div class="Columns__Item-sc-10ug1wf-1 eBAVoM">
#           <p class="Paragraph-sc-1iyax29-0 Columns__ItemHeading-sc-10ug1wf-3 cvdqge iSItOL">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://www.usnews.com/news/elections">
#             Elections
#            </a>
#           </p>
#           <div class="Columns__Items-sc-10ug1wf-2 gtptbF sm-hide md-hide">
#           </div>
#          </div>
#          <div class="Columns__Item-sc-10ug1wf-1 eBAVoM">
#           <p class="Paragraph-sc-1iyax29-0 Columns__ItemHeading-sc-10ug1wf-3 cvdqge iSItOL">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://www.usnews.com/news/live-events">
#             Events
#            </a>
#           </p>
#           <div class="Columns__Items-sc-10ug1wf-2 gtptbF sm-hide md-hide">
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="Content-sc-837ada-0 kkKJUL lg-hide content">
#        <div class="Links__LinksWrapper-sc-1vd0nbr-3 gSoJRm">
#         <div class="Links__Container-sc-1vd0nbr-0 eQltFd footer-link-container">
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://www.usnews.com/news/best-countries">
#             Best Countries
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://www.usnews.com/news/best-states">
#             Best States
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://www.usnews.com/news/healthiest-communities">
#             Healthiest Communities
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://www.usnews.com/news">
#             News
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://www.usnews.com/news/the-report">
#             The Report
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://www.usnews.com/photos">
#             Photos
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://www.usnews.com/news/elections">
#             Elections
#            </a>
#           </p>
#          </div>
#          <div class="Links__Item-sc-1vd0nbr-1 eGtlgA">
#           <p class="Paragraph-sc-1iyax29-0 Links__ItemHeading-sc-1vd0nbr-2 cvdqge hrwQpq">
#            <a class="Anchor-byh49a-0 hWoTvt" href="https://www.usnews.com/news/live-events">
#             Events
#            </a>
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="Divider__HorizontalRule-xr0ge4-0 gFPwwu" color="#3F4451" spacing="0">
#       </div>
#       <div class="Content-sc-837ada-0 kkKJUL content">
#        <div class="Info__Container-sc-1vdhah7-0 grQneG">
#         <a href="https://www.usnews.com">
#          <img alt="U.S. News &amp; World Report" class="mb4 lg-mb0" height="40px" src="https://www.usnews.com/static/img/usn-logo-large.svg" width="160px"/>
#         </a>
#         <div class="Info__Grow-sc-1vdhah7-1 eFGqdH">
#          <div class="Info__Left-sc-1vdhah7-3 jXuJkM">
#           <div class="Info__Links-sc-1vdhah7-5 elzsCr" spacing="3">
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="https://www.usnews.com/info/features/about-usnews">
#              About
#              <span class="sm-hide md-hide">
#               U.S. News
#              </span>
#             </a>
#            </div>
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="https://www.usnews.com/about-us/editorial-guidelines">
#              Editorial Guidelines
#             </a>
#            </div>
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="https://www.usnews.com/info/features/contact">
#              Contact
#             </a>
#            </div>
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="https://www.usnews.com/info/blogs/press-room">
#              Press
#             </a>
#            </div>
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="https://mediakit.usnews.com">
#              Advertise
#             </a>
#            </div>
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="http://emailprefs.usnews.com/emailprefs/newsletters-index">
#              Newsletters
#             </a>
#            </div>
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="https://www.usnews.com/info/features/employment">
#              Jobs
#             </a>
#            </div>
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="https://www.usnews.com/info/features/sitemap">
#              Site Map
#             </a>
#            </div>
#            <div class="Info__LinkContainer-sc-1vdhah7-6 klDsYN">
#             <a class="Anchor-byh49a-0 Info__Link-sc-1vdhah7-7 hvHhBk hsuboz" href="https://www.usnews.com/products/features/home?src=usnfooter">
#              Store
#             </a>
#            </div>
#           </div>
#           <div class="SocialIcons__Container-sc-18livsa-0 icFFld Info__FooterIcons-sc-1vdhah7-2 dhgryP mb5 lg-mb4 lg-hide">
#            <a aria-label="U.S. News &amp; World Report Facebook page" href="https://www.facebook.com/usnewsandworldreport" rel="noopener" target="_blank">
#             <svg class="Icon-sc-9wq8ul-0 SocialIcons__Facebook-sc-18livsa-1 hiHdJZ hSdiep" fill="white" height="1.5rem" role="img" width="1.5rem">
#              <use filter="0" xlink:href="#facebook">
#              </use>
#             </svg>
#            </a>
#            <a aria-label="U.S. News &amp; World Report Twitter page" href="https://twitter.com/usnews" rel="noopener" target="_blank">
#             <svg class="Icon-sc-9wq8ul-0 SocialIcons__Twitter-sc-18livsa-2 hiHdJZ fBiLxn" fill="white" height="1.5rem" role="img" width="1.5rem">
#              <use filter="0" xlink:href="#twitter">
#              </use>
#             </svg>
#            </a>
#           </div>
#           <div class="Info__Bottom-sc-1vdhah7-8 dmmajP">
#            <span class="Span-sc-19wk4id-0 Info__Copyright-sc-1vdhah7-9 lnnsuc jAudCl" size="2">
#             Copyright
#             <!-- -->
#             2023
#             <!-- -->
#             © U.S. News &amp; World Report L.P.
#            </span>
#            <span class="Span-sc-19wk4id-0 Info__Terms-sc-1vdhah7-10 lnnsuc fXTuRU" size="2">
#             <a class="Anchor-byh49a-0 PlBer" href="https://www.usnews.com/info/features/terms">
#              Terms &amp; Conditions
#             </a>
#             /
#             <a class="Anchor-byh49a-0 PlBer" href="https://www.usnews.com/features/info/privacy">
#              Privacy Policy
#             </a>
#             /
#             <a class="Anchor-byh49a-0 PlBer" href="https://www.usnews.com/features/info/privacy/ccpa">
#              California Privacy Notice
#             </a>
#             /
#             <a class="Anchor-byh49a-0 PlBer" href="https://www.usnews.com/features/info/privacy/ccpa/do-not-sell">
#              California Do Not Sell My Personal Information Request
#             </a>
#            </span>
#           </div>
#          </div>
#          <div class="Info__Right-sc-1vdhah7-4 fzQSBo sm-hide md-hide">
#           <div class="SocialIcons__Container-sc-18livsa-0 icFFld mb5 lg-mb2">
#            <a aria-label="U.S. News &amp; World Report Facebook page" href="https://www.facebook.com/usnewsandworldreport" rel="noopener" target="_blank">
#             <svg class="Icon-sc-9wq8ul-0 SocialIcons__Facebook-sc-18livsa-1 hiHdJZ hSdiep" fill="white" height="1.5rem" role="img" width="1.5rem">
#              <use filter="0" xlink:href="#facebook">
#              </use>
#             </svg>
#            </a>
#            <a aria-label="U.S. News &amp; World Report Twitter page" href="https://twitter.com/usnews" rel="noopener" target="_blank">
#             <svg class="Icon-sc-9wq8ul-0 SocialIcons__Twitter-sc-18livsa-2 hiHdJZ fBiLxn" fill="white" height="1.5rem" role="img" width="1.5rem">
#              <use filter="0" xlink:href="#twitter">
#              </use>
#             </svg>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </footer>
#     </div>
#    </react-trigger>
#    <div class="overlay__Container-sc-1mwbfqy-0 eJAyFO">
#    </div>
#    <react-trigger trigger="false">
#    </react-trigger>
#   </main>
#   <div id="footer-spacer">
#   </div>
#   <script>
#    window.__SERVER_STATE__ = {"page":"containers\u002Fpages\u002Fbrightspot\u002Farticle-rail.js"};
#                 window.__CUSTOM_ELEMENTS__ = ["src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js","src\u002Fcomponents\u002FcustomElements\u002FReactTrigger\u002Findex.js"];
#                 window.__DEFER_REACT__ = false;
#                 window['__PAGE_CONTEXT_QUERY_STATE__'] = {"src\u002Fcomponents\u002Futil\u002FGlobalHelmet.js":{"data":{"meta_tags":[{"name":"brightspot.contentId","content":"00000185-cfd1-de18-a7bf-fff139c50000"},{"property":"og:site_name","content":"US News & World Report"},{"property":"og:title","content":"Existing Homes Fall 1.5% in December, Marking 11th Month of Declines"},{"property":"og:description","content":"The performance was better than expected and prices inched up a little from a year ago."},{"property":"og:url","content":"\u002F\u002Fwww.usnews.com\u002Fnews\u002Feconomy\u002Farticles\u002F2023-01-20\u002Fexisting-homes-fall-1-5-in-december-marking-11th-month-of-declines"},{"property":"og:image","content":"https:\u002F\u002Fwww.usnews.com\u002Fdims4\u002FUSNEWS\u002F29bc898\u002F2147483647\u002Fthumbnail\u002F970x647\u002Fquality\u002F85\u002F?url=https%3A%2F%2Fwww.usnews.com%2Fcmsmedia%2Fb0%2F51%2F0dfcff14480db32e15ee949e8507%2Fgettyimages-1457475362.jpg"},{"property":"og:image:secure_url","content":"https:\u002F\u002Fwww.usnews.com\u002Fdims4\u002FUSNEWS\u002F29bc898\u002F2147483647\u002Fthumbnail\u002F970x647\u002Fquality\u002F85\u002F?url=https%3A%2F%2Fwww.usnews.com%2Fcmsmedia%2Fb0%2F51%2F0dfcff14480db32e15ee949e8507%2Fgettyimages-1457475362.jpg"},{"property":"twitter:image","content":"https:\u002F\u002Fwww.usnews.com\u002Fdims4\u002FUSNEWS\u002F29bc898\u002F2147483647\u002Fthumbnail\u002F970x647\u002Fquality\u002F85\u002F?url=https%3A%2F%2Fwww.usnews.com%2Fcmsmedia%2Fb0%2F51%2F0dfcff14480db32e15ee949e8507%2Fgettyimages-1457475362.jpg"},{"property":"og:type","content":"article"},{"property":"og:site_name","content":"US News & World Report"},{"property":"og:url","content":"https:\u002F\u002Fwww.usnews.com\u002Fnews\u002Feconomy\u002Farticles\u002F2023-01-20\u002Fexisting-homes-fall-1-5-in-december-marking-11th-month-of-declines"},{"name":"twitter:card","content":"summary_large_image"},{"name":"twitter:site","content":"@USNews"},{"name":"twitter:title","content":"Existing Homes Fall 1.5% in December, Marking 11th Month of Declines"},{"name":"twitter:description","content":"The performance was better than expected and prices inched up a little from a year ago."},{"name":"google-site-verification","content":"owJBuFHD3VHcTSsnPSOYizmUcs3GSBjbx09vBbBi1MM"},{"name":"msvalidate.01","content":"A8E47FA91124063A4A9C78AD5273DC0F"},{"property":"fb:app_id","content":"130063997038366"},{"property":"sailthru.date","content":"2023-01-20T10:44Z"},{"property":"sailthru.author","content":"Tim Smart"},{"property":"sailthru.site_portal","content":"Civic"},{"property":"sailthru.description","content":"The performance was better than expected and prices inched up a little from a year ago."},{"property":"sailthru.title","content":"Existing Homes Fall 1.5% in December, Marking 11th Month of Declines"},{"property":"sailthru.vertical","content":"News"},{"property":"vertical","content":"News"},{"property":"sailthru.image.full","content":"https:\u002F\u002Fwww.usnews.com\u002Fdims4\u002FUSNEWS\u002F29bc898\u002F2147483647\u002Fthumbnail\u002F970x647\u002Fquality\u002F85\u002F?url=https%3A%2F%2Fwww.usnews.com%2Fcmsmedia%2Fb0%2F51%2F0dfcff14480db32e15ee949e8507%2Fgettyimages-1457475362.jpg"},{"property":"sailthru.tags","content":"economy,housing,housing-market,picks"},{"property":"preview","content":"Sales of existing homes slid 1.5% in December, somewhat better than expected but the 11th straight month of decline, the National Association of Realtors said on Friday. The number was better than estimates of a 3.4% drop and brings the annual rate of home sales just a hair above 4 million. Sales ..."}],"utag_data":{"bucket_tags":["picks","economy","national-news"],"article_byline":"Tim Smart","page_type":"article","site_product_section":"Article","site_product":"Economy","article_embedded_gallery":"true","suppress_img_flag":false,"site_portal":"Civic","primary_tag":"economy","article_publish_date":"2023-01-20","site_product_subsection":"","p ...
#   </script>
#   <!-- %CSS_REGRESSION_TESTING_SCRIPT_PLACEHOLDER% -->
#   <noscript>
#    <img src="https://www.usnews.com/akam/13/pixel_2adb981c?a=dD0zZGFhNjFmMjg4NjUwZjgxYjk5OWMyYTM2MTc0ODc5ODU0ZjRiMjdmJmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;"/>
#   </noscript>
#   <script src="/44S-T7E0WZ_FBlgpKFYLFgQCXtw/cYf3QtbS/ejRAYyE8BQU/eCJ/qZXtLd0w" type="text/javascript">
#   </script>
#  </body>
# </html>

# %% [markdown]
# 10. read + print the header as well as the first 3 sentences of the main body to the screen

# %%
sentences = []
def main():
	try:
		url= url_list[1]
		my_headers = {'User-Agent': 'Mozilla/5.0'}
		page = requests.get(url, headers=my_headers)
		# Create a beautifulsoup object
		soup = BeautifulSoup(page.text, 'lxml')
		# find <p> that immediately follows <div> of class "col-md-6.
		list_of_contents = soup.select("h1.Heading-sc-1w5xk2o-0.iQhOvV")
		list_of_contents_2 = soup.select("div.Box-w0dun1-0.article-body__ArticleBox-sc-138p7q2-2.dWWnRo.eYFKbH div.Raw-slyvem-0.bCYKCn")
		# prints the HTML content to the screen (almost only text here
		# just need to replaces "&nbsp;" with " ")
		for i in list_of_contents:
			a = i.text
			print(i.text)
		for i in list_of_contents_2:
			split = re.findall(r'(.+?[.!](?:0-9| |$))', i.text)
			left_sen = 3 - len(sentences)
			find = len(split)
			for i in range(min(find, left_sen)):
				sentences.append(split[i])
			if len(sentences) == 3:
				break
		return a
	except:
		print("Problem with the connection...")

if __name__ == '__main__':
	main()

print(sentences)
# Out:
# Existing Homes Fall 1.5% in December, Marking 11th Month of Declines
# ['Sales of existing homes slid 1.5% in December, somewhat better than expected but the 11th straight month of decline, the National Association of Realtors said on Friday.', 'The number was better than estimates of a 3.4% drop and brings the annual rate of home sales just a hair above 4 million. ', 'Sales are now down 34% from year-ago levels.']
